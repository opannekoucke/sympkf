# %% [markdown]
# O. Pannekoucke$^{1,2,3}$
#
# $^1$ INPT-ENM, Toulouse, France
#
# $^2$ CNRM, Université de Toulouse, Météo-France, CNRS, Toulouse, France
#
# $^3$ CERFACS, Toulouse, France
#
# (olivier.pannekoucke@meteo.fr)

# %% [markdown]
# **Abstract**
#
# This notebook illustrates the use of sympkf to build and handle the PKF dynamics associated with the harmonic oscillator as 2D fields given by
# $$\left\{\begin{array}{c}
# \partial_t u =v\\
# \partial_t v =-u
# \end{array}\right.$$
# where $u$ and $v$ are functions of $t,x,y$.
# For this dynamics, the resulting PKF system is not closed because of the cros-correlation.

# %% [markdown]
# # Definition of the 2D multivariate dynamics

# %%
import sympy
sympy.init_printing()

# %% [markdown]
# **Definition of the dynamics from sympy tools**

# %%
from sympy import Function, Derivative, Eq, symbols
from sympkf import SymbolicPKF, t

# %%
x, y  = symbols('x y')
u = Function('u')(t,x,y)
v = Function('v')(t,x,y)
dynamics = [Eq(Derivative(u,t), v), Eq(Derivative(v,t), -u)]
dynamics
# Out:
# ⎡∂                            ∂                           ⎤
# ⎢──(u(t, x, y)) = v(t, x, y), ──(v(t, x, y)) = -u(t, x, y)⎥
# ⎣∂t                           ∂t                          ⎦

# %% [markdown]
# # Computation of the PKF dynamics by using SymPKF

# %%
pkf_dynamics = SymbolicPKF(dynamics)

# %%
for equation in pkf_dynamics.in_metric:    display(equation)
# Out:
# ∂
# ──(u(t, x, y)) = v(t, x, y)
# ∂t
# ∂
# ──(v(t, x, y)) = -u(t, x, y)
# ∂t
# ∂
# ──({V_{u}}(t, x, y)) = 2⋅Vᵤᵥ(t, x, y)
# ∂t
# ∂
# ──({V_{v}}(t, x, y)) = -2⋅Vᵤᵥ(t, x, y)
# ∂t
# ∂
# ──(Vᵤᵥ(t, x, y)) = -{V_{u}}(t, x, y) + {V_{v}}(t, x, y)
# ∂t
#                                                                      _________
#                                                                  2⋅╲╱ {V_{v}}(
# ∂                           2⋅Vᵤᵥ(t, x, y)⋅{g_{u,xx}}(t, x, y)
# ──({g_{u,xx}}(t, x, y)) = - ────────────────────────────────── + ─────────────
# ∂t                                   {V_{u}}(t, x, y)
#
#
# _________            ⎛∂                                 ∂
# t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t
#                      ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                __________________
#                              ╲╱ {V_{u}}(t, x, y)
#
#            ⎞              ⎛                              ∂
# , x, y, ω))⎟   Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(
#            ⎠              ⎝                              ∂x
# ──────────── + ───────────────────────────────────────────────────────────────
#                                              __________________   ____________
#                                            ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t,
#
#             ⎞ ∂                        __________________            ⎛
# t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜{\vareps
#             ⎠ ∂x                                                     ⎝
# ────────────────────────────────── - ─────────────────────────────────────────
# ______
# x, y)
#
#                       ∂                                ⎞ ∂
# ilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                       ∂x                               ⎠ ∂x
# ─────────────────────────────────────────────────────────────────────────────
#                3/2
#         {V_{u}}   (t, x, y)
#                                                                    ___________
#                                                                  ╲╱ {V_{v}}(t,
# ∂                           2⋅Vᵤᵥ(t, x, y)⋅{g_{u,xy}}(t, x, y)
# ──({g_{u,xy}}(t, x, y)) = - ────────────────────────────────── + ─────────────
# ∂t                                   {V_{u}}(t, x, y)
#
#
# _______            ⎛∂                                 ∂
#  x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                    ⎝∂x                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                               __________________
#                             ╲╱ {V_{u}}(t, x, y)
#
#          ⎞     __________________            ⎛∂
# x, y, ω))⎟   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω)
#          ⎠                                   ⎝∂y
# ────────── + ─────────────────────────────────────────────────────────────────
#                                                         __________________
#                                                       ╲╱ {V_{u}}(t, x, y)
#
#   ∂                                ⎞              ⎛
# )⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   Expectation⎜{\varepsilon_{v}}(t, x, y,
#   ∂x                               ⎠              ⎝
# ──────────────────────────────────── + ───────────────────────────────────────
#                                                                       ________
#                                                                   2⋅╲╱ {V_{u}}
#
#    ∂                                ⎞ ∂                                 ⎛
# ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\var
#    ∂x                               ⎠ ∂y                                ⎝
# ────────────────────────────────────────────────────────── + ─────────────────
# __________   __________________
# (t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                          ∂                                ⎞ ∂
# epsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y
#                          ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#               __________________   __________________
#           2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#        __________________            ⎛                              ∂
# ))   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varep
#                                      ⎝                              ∂x
# ── - ─────────────────────────────────────────────────────────────────────────
#                                                               3/2
#                                                      2⋅{V_{u}}   (t, x, y)
#
#                        ⎞ ∂                        __________________
# silon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅Expectati
#                        ⎠ ∂y
# ───────────────────────────────────────────── - ──────────────────────────────
#
#
#
#   ⎛                              ∂                                ⎞ ∂
# on⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}
#   ⎝                              ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                            3/2
#                   2⋅{V_{u}}   (t, x, y)
#
#
# (t, x, y))
#
# ──────────
#                                                                      _________
#                                                                  2⋅╲╱ {V_{v}}(
# ∂                           2⋅Vᵤᵥ(t, x, y)⋅{g_{u,yy}}(t, x, y)
# ──({g_{u,yy}}(t, x, y)) = - ────────────────────────────────── + ─────────────
# ∂t                                   {V_{u}}(t, x, y)
#
#
# _________            ⎛∂                                 ∂
# t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t
#                      ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                __________________
#                              ╲╱ {V_{u}}(t, x, y)
#
#            ⎞              ⎛                              ∂
# , x, y, ω))⎟   Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(
#            ⎠              ⎝                              ∂y
# ──────────── + ───────────────────────────────────────────────────────────────
#                                              __________________   ____________
#                                            ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t,
#
#             ⎞ ∂                        __________________            ⎛
# t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜{\vareps
#             ⎠ ∂y                                                     ⎝
# ────────────────────────────────── - ─────────────────────────────────────────
# ______
# x, y)
#
#                       ∂                                ⎞ ∂
# ilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                       ∂y                               ⎠ ∂y
# ─────────────────────────────────────────────────────────────────────────────
#                3/2
#         {V_{u}}   (t, x, y)
#                                                                    ___________
#                                                                2⋅╲╱ {V_{u}}(t,
# ∂                         2⋅Vᵤᵥ(t, x, y)⋅{g_{v,xx}}(t, x, y)
# ──({g_{v,xx}}(t, x, y)) = ────────────────────────────────── - ───────────────
# ∂t                                 {V_{v}}(t, x, y)
#
#
# _______            ⎛∂                                 ∂
#  x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                    ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                              __________________
#                            ╲╱ {V_{v}}(t, x, y)
#
#          ⎞     __________________            ⎛                              ∂
# x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──
#          ⎠                                   ⎝                              ∂x
# ────────── + ─────────────────────────────────────────────────────────────────
#                                                                      3/2
#                                                               {V_{v}}   (t, x,
#
#                                ⎞ ∂                                 ⎛
# ({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\varepsil
#                                ⎠ ∂x                                ⎝
# ───────────────────────────────────────────────────── - ──────────────────────
#
#  y)
#
#                     ∂                                ⎞ ∂
# on_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                     ∂x                               ⎠ ∂x
# ───────────────────────────────────────────────────────────────────────────
#         __________________   __________________
#       ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#                                                                  _____________
#                                                                ╲╱ {V_{u}}(t, x
# ∂                         2⋅Vᵤᵥ(t, x, y)⋅{g_{v,xy}}(t, x, y)
# ──({g_{v,xy}}(t, x, y)) = ────────────────────────────────── - ───────────────
# ∂t                                 {V_{v}}(t, x, y)
#
#
# _____            ⎛∂                                 ∂
# , y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x,
#                  ⎝∂x                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                             __________________
#                           ╲╱ {V_{v}}(t, x, y)
#
#        ⎞     __________________            ⎛∂
#  y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅
#        ⎠                                   ⎝∂y
# ──────── - ───────────────────────────────────────────────────────────────────
#                                                       __________________
#                                                     ╲╱ {V_{v}}(t, x, y)
#
# ∂                                ⎞     __________________            ⎛
# ──({\varepsilon_{v}}(t, x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\vareps
# ∂x                               ⎠                                   ⎝
# ────────────────────────────────── + ─────────────────────────────────────────
#
#
#
#                       ∂                                ⎞ ∂
# ilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))
#                       ∂x                               ⎠ ∂y
# ─────────────────────────────────────────────────────────────────────────────
#                 3/2
#        2⋅{V_{v}}   (t, x, y)
#
#     __________________            ⎛                              ∂
#   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsil
#                                   ⎝                              ∂y
# + ────────────────────────────────────────────────────────────────────────────
#                                                            3/2
#                                                   2⋅{V_{v}}   (t, x, y)
#
#                     ⎞ ∂                                 ⎛
# on_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\varepsilon_{u}}(t,
#                     ⎠ ∂x                                ⎝
# ────────────────────────────────────────── - ─────────────────────────────────
#                                                                             __
#                                                                         2⋅╲╱ {
#
#          ∂                                ⎞ ∂
# x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   Expectation
#          ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────── - ───────────
# ________________   __________________
# V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
# ⎛                              ∂                                ⎞ ∂
# ⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t
# ⎝                              ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                     __________________   __________________
#                 2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#
# , x, y))
#
# ────────
#                                                                    ___________
#                                                                2⋅╲╱ {V_{u}}(t,
# ∂                         2⋅Vᵤᵥ(t, x, y)⋅{g_{v,yy}}(t, x, y)
# ──({g_{v,yy}}(t, x, y)) = ────────────────────────────────── - ───────────────
# ∂t                                 {V_{v}}(t, x, y)
#
#
# _______            ⎛∂                                 ∂
#  x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                    ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                              __________________
#                            ╲╱ {V_{v}}(t, x, y)
#
#          ⎞     __________________            ⎛                              ∂
# x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──
#          ⎠                                   ⎝                              ∂y
# ────────── + ─────────────────────────────────────────────────────────────────
#                                                                      3/2
#                                                               {V_{v}}   (t, x,
#
#                                ⎞ ∂                                 ⎛
# ({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\varepsil
#                                ⎠ ∂y                                ⎝
# ───────────────────────────────────────────────────── - ──────────────────────
#
#  y)
#
#                     ∂                                ⎞ ∂
# on_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                     ∂y                               ⎠ ∂y
# ───────────────────────────────────────────────────────────────────────────
#         __________________   __________________
#       ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)

# %%
for equation in pkf_dynamics.in_aspect:    display(equation)
# Out:
# ∂
# ──(u(t, x, y)) = v(t, x, y)
# ∂t
# ∂
# ──(v(t, x, y)) = -u(t, x, y)
# ∂t
# ∂
# ──({V_{u}}(t, x, y)) = 2⋅Vᵤᵥ(t, x, y)
# ∂t
# ∂
# ──({V_{v}}(t, x, y)) = -2⋅Vᵤᵥ(t, x, y)
# ∂t
# ∂
# ──(Vᵤᵥ(t, x, y)) = -{V_{u}}(t, x, y) + {V_{v}}(t, x, y)
# ∂t
#                                                                    ___________
#                                                                2⋅╲╱ {V_{v}}(t,
# ∂                         2⋅Vᵤᵥ(t, x, y)⋅{s_{u,xx}}(t, x, y)
# ──({s_{u,xx}}(t, x, y)) = ────────────────────────────────── - ───────────────
# ∂t                                 {V_{u}}(t, x, y)
#
#
# _______           2                     ⎛∂                                 ∂
#  x, y) ⋅{s_{u,xx}} (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──(
#                                         ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                        __________________
#                                      ╲╱ {V_{u}}(t, x, y)
#
#                               ⎞       __________________
# {\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{
#                               ⎠
# ─────────────────────────────── - ────────────────────────────────────────────
#
#
#
#                               ⎛∂                                 ∂
# s_{u,xy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsil
#                               ⎝∂x                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                     __________________
#                   ╲╱ {V_{u}}(t, x, y)
#
#                     ⎞       __________________
# on_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(
#                     ⎠
# ───────────────────── - ──────────────────────────────────────────────────────
#
#
#
#                     ⎛∂                                 ∂
# t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                     ⎝∂y                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#           __________________
#         ╲╱ {V_{u}}(t, x, y)
#
#           ⎞       __________________           2                     ⎛∂
#  x, y, ω))⎟   2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜──({\var
#           ⎠                                                          ⎝∂y
# ─────────── - ────────────────────────────────────────────────────────────────
#                                                                     __________
#                                                                   ╲╱ {V_{u}}(t
#
#                           ∂                                ⎞             2
# epsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   {s_{u,xx}} (t,
#                           ∂y                               ⎠
# ──────────────────────────────────────────────────────────── - ───────────────
# ________
# , x, y)
#
#                  ⎛                              ∂
# x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y,
#                  ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                          __________________   __________________
#                        ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#    ⎞ ∂
# ω))⎟⋅──({V_{v}}(t, x, y))   {s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅Expectatio
#    ⎠ ∂x
# ───────────────────────── - ──────────────────────────────────────────────────
#
#                                                                             ╲╱
#
#  ⎛                              ∂                                ⎞ ∂
# n⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(
#  ⎝                              ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
# __________________   __________________
#  {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                                ⎛
# t, x, y))   {s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅Expectation⎜{\varepsilon_{
#                                                                ⎝
# ───────── - ──────────────────────────────────────────────────────────────────
#                                                               ________________
#                                                             ╲╱ {V_{u}}(t, x, y
#
#                 ∂                                ⎞ ∂
# v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {s_{
#                 ∂y                               ⎠ ∂x
# ─────────────────────────────────────────────────────────────────────── - ────
# __   __________________
# ) ⋅╲╱ {V_{v}}(t, x, y)
#
#       2                     ⎛                              ∂
# u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}
#                             ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                     __________________   __________________
#                                   ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#               ⎞ ∂                        __________________           2
# }(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}} (t, x,
#               ⎠ ∂y
# ──────────────────────────────────── + ───────────────────────────────────────
#
#
#
#               ⎛                              ∂
# y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))
#               ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                             3/2
#                      {V_{u}}   (t, x, y)
#
# ⎞ ∂                        __________________
# ⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t
# ⎠ ∂x
# ────────────────────── + ─────────────────────────────────────────────────────
#
#
#
#                    ⎛                              ∂
# , x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y
#                    ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                        3/2
#                 {V_{u}}   (t, x, y)
#
#      ⎞ ∂                        __________________
# , ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,x
#      ⎠ ∂y
# ─────────────────────────── + ────────────────────────────────────────────────
#
#
#
#                         ⎛                              ∂
# y}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t,
#                         ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                             3/2
#                      {V_{u}}   (t, x, y)
#
#           ⎞ ∂                        __________________           2
#  x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)⋅E
#           ⎠ ∂x
# ──────────────────────────────── + ───────────────────────────────────────────
#
#
#
#           ⎛                              ∂                                ⎞ ∂
# xpectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──
#           ⎝                              ∂y                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                         3/2
#                  {V_{u}}   (t, x, y)
#
#
# ({V_{u}}(t, x, y))
#
# ──────────────────
#                                                                    ___________
#                                                                2⋅╲╱ {V_{v}}(t,
# ∂                         2⋅Vᵤᵥ(t, x, y)⋅{s_{u,xy}}(t, x, y)
# ──({s_{u,xy}}(t, x, y)) = ────────────────────────────────── - ───────────────
# ∂t                                 {V_{u}}(t, x, y)
#
#
# _______                                                    ⎛∂
#  x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u
#                                                            ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                                  __________________
#                                                ╲╱ {V_{u}}(t, x, y)
#
#                 ∂                                ⎞     __________________
# }}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   ╲╱ {V_{v}}(t, x, y) ⋅{s_{
#                 ∂x                               ⎠
# ────────────────────────────────────────────────── - ─────────────────────────
#
#
#
#                                                ⎛∂
# u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y,
#                                                ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                       __________________
#                                     ╲╱ {V_{u}}(t, x, y)
#
#     ∂                                ⎞     __________________
# ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x,
#     ∂y                               ⎠
# ────────────────────────────────────── - ─────────────────────────────────────
#
#
#
#                                    ⎛∂                                 ∂
#  y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\var
#                                    ⎝∂y                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                           __________________
#                         ╲╱ {V_{u}}(t, x, y)
#
#                          ⎞     __________________           2
# epsilon_{v}}(t, x, y, ω))⎟   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)⋅Expecta
#                          ⎠
# ────────────────────────── - ─────────────────────────────────────────────────
#
#
#
#     ⎛∂                                 ∂                                ⎞
# tion⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   ╲╱
#     ⎝∂x                                ∂y                               ⎠
# ───────────────────────────────────────────────────────────────────────── - ──
#     __________________
#   ╲╱ {V_{u}}(t, x, y)
#
# __________________           2                     ⎛∂
#  {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x,
#                                                    ⎝∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                                    __________________
#                                                  ╲╱ {V_{u}}(t, x, y)
#
#         ∂                                ⎞       __________________
#  y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}}
#         ∂x                               ⎠
# ────────────────────────────────────────── - ─────────────────────────────────
#
#
#
#                                          ⎛∂                                 ∂
# (t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──
#                                          ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                __________________
#                              ╲╱ {V_{u}}(t, x, y)
#
#                                ⎞
# ({\varepsilon_{v}}(t, x, y, ω))⎟   {s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅Exp
#                                ⎠
# ──────────────────────────────── - ───────────────────────────────────────────
#
#
#
#         ⎛                              ∂                                ⎞ ∂
# ectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({
#         ⎝                              ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#        __________________   __________________
#      ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                                       ⎛
# V_{v}}(t, x, y))   {s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varep
#                                                                       ⎝
# ──────────────── - ───────────────────────────────────────────────────────────
#                                                                       ________
#                                                                   2⋅╲╱ {V_{u}}
#
#                        ∂                                ⎞ ∂
# silon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))
#                        ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
# __________   __________________
# (t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                       ⎛
#    {s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x,
#                                                       ⎝
#  - ───────────────────────────────────────────────────────────────────────────
#                                                       __________________   ___
#                                                   2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V
#
#        ∂                                ⎞ ∂                                2
#  y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {s_{u,xy}} (t
#        ∂y                               ⎠ ∂x
# ────────────────────────────────────────────────────────────── - ─────────────
# _______________
# _{v}}(t, x, y)
#
#                    ⎛                              ∂
# , x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y
#                    ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                             __________________   __________________
#                         2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#      ⎞ ∂                                2                     ⎛
# , ω))⎟⋅──({V_{v}}(t, x, y))   {s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v
#      ⎠ ∂y                                                     ⎝
# ─────────────────────────── - ────────────────────────────────────────────────
#                                                                        _______
#                                                                    2⋅╲╱ {V_{u}
#
#                ∂                                ⎞ ∂
# }}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {s_{u
#                ∂y                               ⎠ ∂x
# ────────────────────────────────────────────────────────────────────── - ─────
# ___________   __________________
# }(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                               ⎛                              ∂
# ,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅─
#                                               ⎝                              ∂
# ──────────────────────────────────────────────────────────────────────────────
#                                              __________________   ____________
#                                            ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t,
#
#                                 ⎞ ∂                        __________________
# ─({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅
# y                               ⎠ ∂y
# ────────────────────────────────────────────────────── + ─────────────────────
# ______
# x, y)
#
#                                                    ⎛
# {s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y,
#                                                    ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                        3/2
#                                                 {V_{u}}   (t, x, y)
#
#     ∂                                ⎞ ∂                        ______________
#  ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x,
#     ∂x                               ⎠ ∂x
# ─────────────────────────────────────────────────────────── + ────────────────
#
#
#
# ____                                                    ⎛
#  y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t,
#                                                         ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                              3/2
#                                                     2⋅{V_{u}}   (t, x, y)
#
#          ∂                                ⎞ ∂                        _________
# x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(
#          ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────── + ───────────
#
#
#
# _________                                                    ⎛
# t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}
#                                                              ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                   3/2
#                                                          2⋅{V_{u}}   (t, x, y)
#
#               ∂                                ⎞ ∂                        ____
# }(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_
#               ∂y                               ⎠ ∂x
# ───────────────────────────────────────────────────────────────────── + ──────
#
#
#
# ______________           2                     ⎛
# {v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅
#                                                ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                               3/2
#                                                      2⋅{V_{u}}   (t, x, y)
#
# ∂                                ⎞ ∂                        __________________
# ──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y)
# ∂x                               ⎠ ∂y
# ─────────────────────────────────────────────────────── + ────────────────────
#
#
#
#            2                     ⎛                              ∂
# ⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilo
#                                  ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                                 3/2
#                                        2⋅{V_{u}}   (t, x, y)
#
#                    ⎞ ∂                        __________________
# n_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}}(t,
#                    ⎠ ∂x
# ───────────────────────────────────────── + ──────────────────────────────────
#
#
#
#                                       ⎛                              ∂
#  x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\vare
#                                       ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                           3/2
#                                    {V_{u}}   (t, x, y)
#
#                         ⎞ ∂
# psilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                         ⎠ ∂y
# ──────────────────────────────────────────────
#                                                                    ___________
#                                                                2⋅╲╱ {V_{v}}(t,
# ∂                         2⋅Vᵤᵥ(t, x, y)⋅{s_{u,yy}}(t, x, y)
# ──({s_{u,yy}}(t, x, y)) = ────────────────────────────────── - ───────────────
# ∂t                                 {V_{u}}(t, x, y)
#
#
# _______           2                     ⎛∂                                 ∂
#  x, y) ⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──(
#                                         ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                        __________________
#                                      ╲╱ {V_{u}}(t, x, y)
#
#                               ⎞       __________________
# {\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}}(t, x, y)⋅{
#                               ⎠
# ─────────────────────────────── - ────────────────────────────────────────────
#
#
#
#                               ⎛∂                                 ∂
# s_{u,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsil
#                               ⎝∂x                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                     __________________
#                   ╲╱ {V_{u}}(t, x, y)
#
#                     ⎞       __________________
# on_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(
#                     ⎠
# ───────────────────── - ──────────────────────────────────────────────────────
#
#
#
#                     ⎛∂                                 ∂
# t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                     ⎝∂y                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#           __________________
#         ╲╱ {V_{u}}(t, x, y)
#
#           ⎞       __________________           2                     ⎛∂
#  x, y, ω))⎟   2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜──({\var
#           ⎠                                                          ⎝∂y
# ─────────── - ────────────────────────────────────────────────────────────────
#                                                                     __________
#                                                                   ╲╱ {V_{u}}(t
#
#                           ∂                                ⎞             2
# epsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   {s_{u,xy}} (t,
#                           ∂y                               ⎠
# ──────────────────────────────────────────────────────────── - ───────────────
# ________
# , x, y)
#
#                  ⎛                              ∂
# x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y,
#                  ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                          __________________   __________________
#                        ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#    ⎞ ∂
# ω))⎟⋅──({V_{v}}(t, x, y))   {s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectatio
#    ⎠ ∂x
# ───────────────────────── - ──────────────────────────────────────────────────
#
#                                                                             ╲╱
#
#  ⎛                              ∂                                ⎞ ∂
# n⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(
#  ⎝                              ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
# __________________   __________________
#  {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                                ⎛
# t, x, y))   {s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{
#                                                                ⎝
# ───────── - ──────────────────────────────────────────────────────────────────
#                                                               ________________
#                                                             ╲╱ {V_{u}}(t, x, y
#
#                 ∂                                ⎞ ∂
# v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {s_{
#                 ∂y                               ⎠ ∂x
# ─────────────────────────────────────────────────────────────────────── - ────
# __   __________________
# ) ⋅╲╱ {V_{v}}(t, x, y)
#
#       2                     ⎛                              ∂
# u,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}
#                             ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                     __________________   __________________
#                                   ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#               ⎞ ∂                        __________________           2
# }(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x,
#               ⎠ ∂y
# ──────────────────────────────────── + ───────────────────────────────────────
#
#
#
#               ⎛                              ∂
# y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))
#               ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                             3/2
#                      {V_{u}}   (t, x, y)
#
# ⎞ ∂                        __________________
# ⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t
# ⎠ ∂x
# ────────────────────── + ─────────────────────────────────────────────────────
#
#
#
#                    ⎛                              ∂
# , x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y
#                    ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                        3/2
#                 {V_{u}}   (t, x, y)
#
#      ⎞ ∂                        __________________
# , ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}}(t, x, y)⋅{s_{u,y
#      ⎠ ∂y
# ─────────────────────────── + ────────────────────────────────────────────────
#
#
#
#                         ⎛                              ∂
# y}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t,
#                         ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                             3/2
#                      {V_{u}}   (t, x, y)
#
#           ⎞ ∂                        __________________           2
#  x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,yy}} (t, x, y)⋅E
#           ⎠ ∂x
# ──────────────────────────────── + ───────────────────────────────────────────
#
#
#
#           ⎛                              ∂                                ⎞ ∂
# xpectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──
#           ⎝                              ∂y                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                         3/2
#                  {V_{u}}   (t, x, y)
#
#
# ({V_{u}}(t, x, y))
#
# ──────────────────
#
#                                                                      _________
# ∂                                                   2⋅Vᵤᵥ(t, x, y)⋅╲╱ {V_{u}}(
# ──({s_{v,xx}}(t, x, y)) = - ──────────────────────────────────────────────────
# ∂t                            __________________        7/2
#                             ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}
#
#
# _________        5/2                    2
# t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}} (t, x, y)⋅{s_{v,yy}}(t, x, y)
# ──────────────────────────────────────────────────────────────────────────────
#                                    __________________        7/2
# }(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{
#
#
#                                                             __________________
#                                            2⋅Vᵤᵥ(t, x, y)⋅╲╱ {V_{u}}(t, x, y)
# ──────────────── + ───────────────────────────────────────────────────────────
#       2              __________________        7/2
# v,xy}} (t, x, y)   ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y
#
#
#         5/2                                        2
# ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,xy}} (t, x, y)
# ──────────────────────────────────────────────────────────────────────────────
#                           __________________        7/2                    2
# )⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t
#
#                                     3                    3
#           2⋅{V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xx}} (t, x, y)⋅{s_{v,yy}}
#
# ─────── + ────────────────────────────────────────────────────────────────────
#                    __________________        7/2
# , x, y)          ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅
#
#                      ⎛∂                                 ∂
# (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t
#                      ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                         __________________        7/2                    2
# {s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t,
#
#            ⎞                             3                    2
# , x, y, ω))⎟   2⋅{V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xx}} (t, x, y)⋅{s_{v
#            ⎠
# ──────────── - ───────────────────────────────────────────────────────────────
#                          __________________        7/2
# x, y)                  ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t,
#
#      2                     ⎛∂                                 ∂
# ,xy}} (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_
#                            ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                               __________________        7/2
# x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}
#
#                  ⎞                             3                    2
# {v}}(t, x, y, ω))⎟   2⋅{V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xx}} (t, x, y)
#                  ⎠
# ────────────────── + ─────────────────────────────────────────────────────────
#  2                                      __________________        7/2
# } (t, x, y)                           ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)
#
#                                                     ⎛∂
# ⋅{s_{v,xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x
#                                                     ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                              __________________        7/2
# ⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t,
#
#          ∂                                ⎞                             3
# , y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅{V_{u}}(t, x, y)⋅{V_{v}} (t, x
#          ∂y                               ⎠
# ─────────────────────────────────────────── + ────────────────────────────────
#                 2                                                _____________
# x, y)⋅{s_{v,xy}} (t, x, y)                                     ╲╱ {V_{u}}(t, x
#
#                2                                                             ⎛
# , y)⋅{s_{v,xx}} (t, x, y)⋅{s_{v,xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜
#                                                                              ⎝
# ──────────────────────────────────────────────────────────────────────────────
# _____        7/2                                                      ________
# , y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}
#
# ∂                                 ∂                                ⎞
# ──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅{V_{u
# ∂y                                ∂x                               ⎠
# ──────────────────────────────────────────────────────────────────── - ───────
# __________        7/2                    2
# (t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)
#
#                    3                                        3
# }}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,xy}} (t, x, y)⋅Expecta
#
# ──────────────────────────────────────────────────────────────────────────────
#   __________________        7/2
# ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x,
#
#     ⎛∂                                 ∂                                ⎞
# tion⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅
#     ⎝∂x                                ∂y                               ⎠
# ───────────────────────────────────────────────────────────────────────── - ──
#        __________________        7/2                    2
# y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)
#
#                         3                                        3
# {V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,xy}} (t, x, y)⋅Ex
#
# ──────────────────────────────────────────────────────────────────────────────
#        __________________        7/2
#      ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t
#
#          ⎛∂                                 ∂                                ⎞
# pectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟
#          ⎝∂y                                ∂x                               ⎠
# ──────────────────────────────────────────────────────────────────────────────
#             __________________        7/2                    2
# , x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)
#
#                              3                                        2
#    2⋅{V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,xy}} (t, x,
#
#  + ───────────────────────────────────────────────────────────────────────────
#                       __________________        7/2
#                     ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x,
#
#                                   ⎛∂                                 ∂
# y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\vare
#                                   ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                            __________________        7/2                    2
# y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (
#
#                         ⎞                                3
# psilon_{v}}(t, x, y, ω))⎟      2⋅{V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xy}}
#                         ⎠
# ───────────────────────── - ──────────────────────────────────────────────────
#                               __________________        7/2
# t, x, y)                    ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}
#
# 4                     ⎛∂                                 ∂
#  (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(
#                       ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                    __________________        7/2
# }(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{
#
#             ⎞                              2                    3
# t, x, y, ω))⎟      {V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xx}} (t, x, y)⋅{s_
#             ⎠
# ──────────────── - ───────────────────────────────────────────────────────────
#       2                             __________________        7/2
# v,xy}} (t, x, y)                  ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_
#
#                             ⎛                              ∂
# {v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}
#                             ⎝                              ∂x
# ...
# ⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {V_{u}}(t, x, y)⋅{V
#  ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────── - ───────────────────
# /2                    2
#   (t, x, y)⋅{s_{v,xy}} (t, x, y)
#
#      2                                                            2
# _{v}} (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,xy}}(t, x, y)⋅{s_{v,yy}} (t, x, y)⋅E
#
# ──────────────────────────────────────────────────────────────────────────────
#         __________________        7/2
#       ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(
#
#           ⎛                              ∂                                ⎞ ∂
# xpectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──
#           ⎝                              ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#              __________________        7/2                    2
# t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)
#
#                                              2
# ({V_{v}}(t, x, y))   {V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s
#
# ────────────────── - ─────────────────────────────────────────────────────────
#                                                 __________________        7/2
#                                               ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (
#
#                             2                     ⎛
# _{v,xy}}(t, x, y)⋅{s_{v,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y,
#                                                   ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                      __________________
# t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}
#
#    ∂                                ⎞ ∂
# ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {V_{u}}(t, x, y)⋅
#    ∂y                               ⎠ ∂x
# ────────────────────────────────────────────────────────── - ─────────────────
#  7/2                    2
# }   (t, x, y)⋅{s_{v,xy}} (t, x, y)                                          ╲╱
#
#        2                                        3                     ⎛
# {V_{v}} (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}} (t, x, y)⋅Expectation⎜{\varep
#                                                                       ⎝
# ──────────────────────────────────────────────────────────────────────────────
# __________________        7/2
#  {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y)
#
#                        ∂                                ⎞ ∂
# silon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))
#                        ∂y                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#      __________________        7/2                    2
#  - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)
#
#                            2                    4                     ⎛
#    {V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xy}} (t, x, y)⋅Expectation⎜{\varep
#                                                                       ⎝
#  + ───────────────────────────────────────────────────────────────────────────
#           __________________        7/2
#         ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}
#
#                        ∂                                ⎞ ∂
# silon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))
#                        ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                __________________        7/2                    2
# }(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)
#
#                            2                    3
#    {V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xy}} (t, x, y)⋅{s_{v,yy}}(t, x, y)
#
#  + ───────────────────────────────────────────────────────────────────────────
#                     __________________        7/2
#                   ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)
#
#             ⎛                              ∂                                ⎞
# ⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅
#             ⎝                              ∂x                               ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                          __________________        7/2                    2
# ⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t,
#
# ∂                                              2                    3
# ──({V_{v}}(t, x, y))   {V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅{s_{v,xy}} (t, x, y)
# ∂y
# ──────────────────── + ───────────────────────────────────────────────────────
#                                         __________________        7/2
#  x, y)                                ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)
#
#                                 ⎛                              ∂
# ⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon
#                                 ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                              __________________        7/2
# ⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t,
#
#                   ⎞ ∂                                              2
# _{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {V_{u}}(t, x, y)⋅{V_{v}} (t, x, y)⋅
#                   ⎠ ∂x
# ──────────────────────────────────────── + ───────────────────────────────────
#                 2                                           __________________
# x, y)⋅{s_{v,xy}} (t, x, y)                                ╲╱ {V_{u}}(t, x, y)
#
#           2                    2                     ⎛
# {s_{v,xy}} (t, x, y)⋅{s_{v,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x,
#                                                      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#         7/2                                                      _____________
# ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x
#
#       ∂                                ⎞ ∂                             3
# y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {V_{v}} (t, x,
#       ∂y                               ⎠ ∂y
# ───────────────────────────────────────────────────────────── + ──────────────
# _____        7/2                    2
# , y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)
#
#                                   2                                         ⎛
#  y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,xy}} (t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{
#                                                                             ⎝
# ──────────────────────────────────────────────────────────────────────────────
#     __________________        7/2
#   ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x
#
#                              ∂                                ⎞ ∂
# \varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t,
#                              ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#          __________________        7/2                    2
# , y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)
#
#                 3                                                            2
# x, y))   {V_{v}} (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,xy}}(t, x, y)⋅{s_{v,yy}}
#
# ────── + ─────────────────────────────────────────────────────────────────────
#                            __________________        7/2
#                          ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t
#
#                      ⎛                              ∂
# (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x,
#                      ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                 __________________        7/2
# , x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,x
#
#        ⎞ ∂                             3
#  y, ω))⎟⋅──({V_{u}}(t, x, y))   {V_{v}} (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,xy
#        ⎠ ∂y
# ───────────────────────────── + ──────────────────────────────────────────────
#    2                                              __________________        7/
# y}} (t, x, y)                                   ╲╱ {V_{u}}(t, x, y) ⋅{V_{v}}
#
#                       2                     ⎛                              ∂
# }}(t, x, y)⋅{s_{v,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──(
#                                             ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
# 2                                                      __________________
#  (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y) ⋅{V_{
#
#                               ⎞ ∂                             3
# {\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {V_{v}} (t, x, y)⋅{s_{v
#                               ⎠ ∂x
# ──────────────────────────────────────────────────── + ───────────────────────
#    7/2                    2                                    _______________
# v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)                         ╲╱ {V_{u}}(t, x,
#
#                          3                     ⎛
# ,xx}}(t, x, y)⋅{s_{v,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅
#                                                ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ___        7/2                                                      __________
# y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t
#
# ∂                                ⎞ ∂                                 3
# ──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))       {V_{v}} (t, x, y
# ∂y                               ⎠ ∂y
# ─────────────────────────────────────────────────────── - ────────────────────
# ________        7/2                    2                    __________________
# , x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)         ╲╱ {V_{u}}(t, x, y)
#
#             4                     ⎛                              ∂
# )⋅{s_{v,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsil
#                                   ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#         7/2                                                      _____________
# ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x
#
#                     ⎞ ∂                                 3                    3
# on_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))       {V_{v}} (t, x, y)⋅{s_{v,xy}}
#                     ⎠ ∂x
# ────────────────────────────────────────────── - ─────────────────────────────
# _____        7/2                    2                    __________________
# , y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)         ╲╱ {V_{u}}(t, x, y) ⋅{V
#
#                                          ⎛                              ∂
# (t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\v
#                                          ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#      7/2                                                      ________________
# _{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x, y
#
#                            ⎞ ∂                             3
# arepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {V_{v}} (t, x, y)⋅{s_{v,xy
#                            ⎠ ∂y
# ───────────────────────────────────────────────── - ──────────────────────────
# __        7/2                    2                          __________________
# ) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)               ╲╱ {V_{u}}(t, x, y)
#
#   3                                         ⎛                              ∂
# }} (t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──(
#                                             ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#         7/2                                                      _____________
# ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(t, x
#
#                               ⎞ ∂                             3
# {\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {V_{v}} (t, x, y)⋅{s_{v
#                               ⎠ ∂x
# ──────────────────────────────────────────────────── - ───────────────────────
# _____        7/2                    2                           ______________
# , y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)                ╲╱ {V_{u}}(t, x,
#
#      2                    2                     ⎛
# ,xy}} (t, x, y)⋅{s_{v,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)
#                                                 ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ____        7/2                                                      _________
#  y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y) - ╲╱ {V_{u}}(
#
#  ∂                                ⎞ ∂
# ⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#  ∂y                               ⎠ ∂y
# ────────────────────────────────────────────────────────
# _________        7/2                    2
# t, x, y) ⋅{V_{v}}   (t, x, y)⋅{s_{v,xy}} (t, x, y)
