# %% [markdown]
# O. Pannekoucke$^{1,2,3}$
#
# $^1$ INPT-ENM, Toulouse, France
#
# $^2$ CNRM, Université de Toulouse, Météo-France, CNRS, Toulouse, France
#
# $^3$ CERFACS, Toulouse, France
#
# (olivier.pannekoucke@meteo.fr)

# %% [markdown]
# **Abstract**
#
# This notebook illustrates the use of sympkf to build and handle the PKF dynamics associated with the harmonic oscillator as 2D fields given by
# $$\left\{\begin{array}{c}
# \partial_t u =-v\\
# \partial_t v =u
# \end{array}\right.$$
# where $u$ and $v$ are functions of $t,x,y$.
# For this dynamics, the resulting PKF system is not closed because of the cros-correlation.

# %% [markdown]
# # Definition of the 2D multivariate dynamics

# %%
import sympy
sympy.init_printing()

# %% [markdown]
# **Definition of the dynamics from sympy tools**

# %%
from sympy import Function, Derivative, Eq, symbols
from sympkf import SymbolicPKF, t

# %%
x, y  = symbols('x y')
u = Function('u')(t,x,y)
v = Function('v')(t,x,y)
dynamics = [Eq(Derivative(u,t), -v), Eq(Derivative(v,t), u)]
dynamics
# Out:
# ⎡∂                             ∂                          ⎤
# ⎢──(u(t, x, y)) = -v(t, x, y), ──(v(t, x, y)) = u(t, x, y)⎥
# ⎣∂t                            ∂t                         ⎦

# %% [markdown]
# # Computation of the PKF dynamics by using SymPKF

# %%
pkf_dynamics = SymbolicPKF(dynamics)

# %%
for equation in pkf_dynamics.in_metric:    display(equation)
# Out:
# ∂
# ──(u(t, x, y)) = -v(t, x, y)
# ∂t
# ∂
# ──(v(t, x, y)) = u(t, x, y)
# ∂t
# ∂
# ──({V_{u}}(t, x, y)) = -2⋅Vᵤᵥ(t, x, y)
# ∂t
# ∂
# ──({V_{v}}(t, x, y)) = 2⋅Vᵤᵥ(t, x, y)
# ∂t
# ∂
# ──(Vᵤᵥ(t, x, y)) = {V_{u}}(t, x, y) - {V_{v}}(t, x, y)
# ∂t
#                                                                    ___________
#                                                                2⋅╲╱ {V_{v}}(t,
# ∂                         2⋅Vᵤᵥ(t, x, y)⋅{g_{u,xx}}(t, x, y)
# ──({g_{u,xx}}(t, x, y)) = ────────────────────────────────── - ───────────────
# ∂t                                 {V_{u}}(t, x, y)
#
#
# _______            ⎛∂                                 ∂
#  x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                    ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                              __________________
#                            ╲╱ {V_{u}}(t, x, y)
#
#          ⎞              ⎛                              ∂
# x, y, ω))⎟   Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t,
#          ⎠              ⎝                              ∂x
# ────────── - ─────────────────────────────────────────────────────────────────
#                                            __________________   ______________
#                                          ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x,
#
#           ⎞ ∂                        __________________            ⎛
#  x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜{\varepsil
#           ⎠ ∂x                                                     ⎝
# ──────────────────────────────── + ───────────────────────────────────────────
# ____
#  y)
#
#                     ∂                                ⎞ ∂
# on_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                     ∂x                               ⎠ ∂x
# ───────────────────────────────────────────────────────────────────────────
#              3/2
#       {V_{u}}   (t, x, y)
#                                                                  _____________
#                                                                ╲╱ {V_{v}}(t, x
# ∂                         2⋅Vᵤᵥ(t, x, y)⋅{g_{u,xy}}(t, x, y)
# ──({g_{u,xy}}(t, x, y)) = ────────────────────────────────── - ───────────────
# ∂t                                 {V_{u}}(t, x, y)
#
#
# _____            ⎛∂                                 ∂
# , y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x,
#                  ⎝∂x                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                             __________________
#                           ╲╱ {V_{u}}(t, x, y)
#
#        ⎞     __________________            ⎛∂
#  y, ω))⎟   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅
#        ⎠                                   ⎝∂y
# ──────── - ───────────────────────────────────────────────────────────────────
#                                                       __________________
#                                                     ╲╱ {V_{u}}(t, x, y)
#
# ∂                                ⎞              ⎛
# ──({\varepsilon_{v}}(t, x, y, ω))⎟   Expectation⎜{\varepsilon_{v}}(t, x, y, ω)
# ∂x                               ⎠              ⎝
# ────────────────────────────────── - ─────────────────────────────────────────
#                                                                     __________
#                                                                 2⋅╲╱ {V_{u}}(t
#
#  ∂                                ⎞ ∂                                 ⎛
# ⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\varep
#  ∂x                               ⎠ ∂y                                ⎝
# ──────────────────────────────────────────────────────── - ───────────────────
# ________   __________________
# , x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                        ∂                                ⎞ ∂
# silon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))
#                        ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#             __________________   __________________
#         2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#      __________________            ⎛                              ∂
#    ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsi
#                                    ⎝                              ∂x
#  + ───────────────────────────────────────────────────────────────────────────
#                                                             3/2
#                                                    2⋅{V_{u}}   (t, x, y)
#
#                      ⎞ ∂                        __________________
# lon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅Expectation
#                      ⎠ ∂y
# ─────────────────────────────────────────── + ────────────────────────────────
#
#
#
# ⎛                              ∂                                ⎞ ∂
# ⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t
# ⎝                              ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                          3/2
#                 2⋅{V_{u}}   (t, x, y)
#
#
# , x, y))
#
# ────────
#                                                                    ___________
#                                                                2⋅╲╱ {V_{v}}(t,
# ∂                         2⋅Vᵤᵥ(t, x, y)⋅{g_{u,yy}}(t, x, y)
# ──({g_{u,yy}}(t, x, y)) = ────────────────────────────────── - ───────────────
# ∂t                                 {V_{u}}(t, x, y)
#
#
# _______            ⎛∂                                 ∂
#  x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                    ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                              __________________
#                            ╲╱ {V_{u}}(t, x, y)
#
#          ⎞              ⎛                              ∂
# x, y, ω))⎟   Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t,
#          ⎠              ⎝                              ∂y
# ────────── - ─────────────────────────────────────────────────────────────────
#                                            __________________   ______________
#                                          ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x,
#
#           ⎞ ∂                        __________________            ⎛
#  x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜{\varepsil
#           ⎠ ∂y                                                     ⎝
# ──────────────────────────────── + ───────────────────────────────────────────
# ____
#  y)
#
#                     ∂                                ⎞ ∂
# on_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                     ∂y                               ⎠ ∂y
# ───────────────────────────────────────────────────────────────────────────
#              3/2
#       {V_{u}}   (t, x, y)
#                                                                      _________
#                                                                  2⋅╲╱ {V_{u}}(
# ∂                           2⋅Vᵤᵥ(t, x, y)⋅{g_{v,xx}}(t, x, y)
# ──({g_{v,xx}}(t, x, y)) = - ────────────────────────────────── + ─────────────
# ∂t                                   {V_{v}}(t, x, y)
#
#
# _________            ⎛∂                                 ∂
# t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t
#                      ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                __________________
#                              ╲╱ {V_{v}}(t, x, y)
#
#            ⎞     __________________            ⎛
# , x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅
#            ⎠                                   ⎝
# ──────────── - ───────────────────────────────────────────────────────────────
#                                                                        3/2
#                                                                 {V_{v}}   (t,
#
# ∂                                ⎞ ∂                                 ⎛
# ──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\vareps
# ∂x                               ⎠ ∂x                                ⎝
# ─────────────────────────────────────────────────────── + ────────────────────
#
# x, y)
#
#                       ∂                                ⎞ ∂
# ilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                       ∂x                               ⎠ ∂x
# ─────────────────────────────────────────────────────────────────────────────
#           __________________   __________________
#         ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#                                                                    ___________
#                                                                  ╲╱ {V_{u}}(t,
# ∂                           2⋅Vᵤᵥ(t, x, y)⋅{g_{v,xy}}(t, x, y)
# ──({g_{v,xy}}(t, x, y)) = - ────────────────────────────────── + ─────────────
# ∂t                                   {V_{v}}(t, x, y)
#
#
# _______            ⎛∂                                 ∂
#  x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                    ⎝∂x                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                               __________________
#                             ╲╱ {V_{v}}(t, x, y)
#
#          ⎞     __________________            ⎛∂
# x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω)
#          ⎠                                   ⎝∂y
# ────────── + ─────────────────────────────────────────────────────────────────
#                                                         __________________
#                                                       ╲╱ {V_{v}}(t, x, y)
#
#   ∂                                ⎞     __________________            ⎛
# )⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\vare
#   ∂x                               ⎠                                   ⎝
# ──────────────────────────────────── - ───────────────────────────────────────
#
#
#
#                         ∂                                ⎞ ∂
# psilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y)
#                         ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                   3/2
#          2⋅{V_{v}}   (t, x, y)
#
#       __________________            ⎛                              ∂
# )   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\vareps
#                                     ⎝                              ∂y
# ─ - ──────────────────────────────────────────────────────────────────────────
#                                                              3/2
#                                                     2⋅{V_{v}}   (t, x, y)
#
#                       ⎞ ∂                                 ⎛
# ilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\varepsilon_{u}}(t
#                       ⎠ ∂x                                ⎝
# ──────────────────────────────────────────── + ───────────────────────────────
#
#                                                                           2⋅╲╱
#
#            ∂                                ⎞ ∂
# , x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   Expectati
#            ∂x                               ⎠ ∂y
# ────────────────────────────────────────────────────────────────── + ─────────
# __________________   __________________
#  {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#   ⎛                              ∂                                ⎞ ∂
# on⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}
#   ⎝                              ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                       __________________   __________________
#                   2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#
# (t, x, y))
#
# ──────────
#                                                                      _________
#                                                                  2⋅╲╱ {V_{u}}(
# ∂                           2⋅Vᵤᵥ(t, x, y)⋅{g_{v,yy}}(t, x, y)
# ──({g_{v,yy}}(t, x, y)) = - ────────────────────────────────── + ─────────────
# ∂t                                   {V_{v}}(t, x, y)
#
#
# _________            ⎛∂                                 ∂
# t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t
#                      ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                __________________
#                              ╲╱ {V_{v}}(t, x, y)
#
#            ⎞     __________________            ⎛
# , x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅
#            ⎠                                   ⎝
# ──────────── - ───────────────────────────────────────────────────────────────
#                                                                        3/2
#                                                                 {V_{v}}   (t,
#
# ∂                                ⎞ ∂                                 ⎛
# ──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\vareps
# ∂y                               ⎠ ∂y                                ⎝
# ─────────────────────────────────────────────────────── + ────────────────────
#
# x, y)
#
#                       ∂                                ⎞ ∂
# ilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                       ∂y                               ⎠ ∂y
# ─────────────────────────────────────────────────────────────────────────────
#           __________________   __________________
#         ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)

# %%
for equation in pkf_dynamics.in_aspect:    display(equation)
# Out:
# ∂
# ──(u(t, x, y)) = -v(t, x, y)
# ∂t
# ∂
# ──(v(t, x, y)) = u(t, x, y)
# ∂t
# ∂
# ──({V_{u}}(t, x, y)) = -2⋅Vᵤᵥ(t, x, y)
# ∂t
# ∂
# ──({V_{v}}(t, x, y)) = 2⋅Vᵤᵥ(t, x, y)
# ∂t
# ∂
# ──(Vᵤᵥ(t, x, y)) = {V_{u}}(t, x, y) - {V_{v}}(t, x, y)
# ∂t
#
#                                                                           5/2
# ∂                                                   2⋅Vᵤᵥ(t, x, y)⋅{V_{u}}   (
# ──({s_{u,xx}}(t, x, y)) = - ──────────────────────────────────────────────────
# ∂t                                 7/2            __________________
#                             {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}
#
#
#            __________________           2
# t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}}(t, x, y)
# ──────────────────────────────────────────────────────────────────────────────
#                                         7/2            __________________
# }(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{
#
#
#                                                                  5/2
#                                            2⋅Vᵤᵥ(t, x, y)⋅{V_{u}}   (t, x, y)⋅
# ──────────────── + ───────────────────────────────────────────────────────────
#       2                   7/2            __________________
# u,xy}} (t, x, y)   {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y
#
#
#   __________________                               2
# ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)
# ──────────────────────────────────────────────────────────────────────────────
#                                7/2            __________________           2
# )⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t
#
#                    3                                     3
#           2⋅{V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}}
#
# ─────── + ────────────────────────────────────────────────────────────────────
#                         7/2            __________________
# , x, y)          {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅
#
#                      ⎛∂                                 ∂
# (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t
#                      ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                              7/2            __________________           2
# {s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t,
#
#            ⎞            3                                     2
# , x, y, ω))⎟   2⋅{V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u
#            ⎠
# ──────────── - ───────────────────────────────────────────────────────────────
#                               7/2            __________________
# x, y)                  {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t,
#
#      2                     ⎛∂                                 ∂
# ,xy}} (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_
#                            ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                    7/2            __________________
# x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}
#
#                  ⎞            3                                     2
# {v}}(t, x, y, ω))⎟   2⋅{V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x, y)
#                  ⎠
# ────────────────── + ─────────────────────────────────────────────────────────
#  2                                           7/2            __________________
# } (t, x, y)                           {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y)
#
#                                                     ⎛∂
# ⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x
#                                                     ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                                   7/2            _____________
# ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x
#
#          ∂                                ⎞            3
# , y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅{V_{u}} (t, x, y)⋅{V_{v}}(t, x
#          ∂y                               ⎠
# ─────────────────────────────────────────── + ────────────────────────────────
# _____           2                                                     7/2
# , y) ⋅{s_{u,xy}} (t, x, y)                                     {V_{u}}   (t, x
#
#                2                                                             ⎛
# , y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜
#                                                                              ⎝
# ──────────────────────────────────────────────────────────────────────────────
#        __________________                                                  7/2
# , y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}
#
# ∂                                 ∂                                ⎞
# ──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅{V_{u
# ∂y                                ∂x                               ⎠
# ──────────────────────────────────────────────────────────────────── - ───────
#             __________________           2
# (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#   3                                                         3
# }} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expecta
#
# ──────────────────────────────────────────────────────────────────────────────
#        7/2            __________________
# {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x,
#
#     ⎛∂                                 ∂                                ⎞
# tion⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅
#     ⎝∂x                                ∂y                               ⎠
# ───────────────────────────────────────────────────────────────────────── - ──
#             7/2            __________________           2
# y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#        3                                                         3
# {V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Ex
#
# ──────────────────────────────────────────────────────────────────────────────
#             7/2            __________________
#      {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t
#
#          ⎛∂                                 ∂                                ⎞
# pectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟
#          ⎝∂y                                ∂x                               ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                  7/2            __________________           2
# , x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#             3                                                         2
#    2⋅{V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x,
#
#  + ───────────────────────────────────────────────────────────────────────────
#                            7/2            __________________
#                     {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x,
#
#                                   ⎛∂                                 ∂
# y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\vare
#                                   ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                 7/2            __________________           2
# y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (
#
#                         ⎞               3
# psilon_{v}}(t, x, y, ω))⎟      2⋅{V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xy}}
#                         ⎠
# ───────────────────────── - ──────────────────────────────────────────────────
#                                    7/2            __________________
# t, x, y)                    {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}
#
# 4                     ⎛∂                                 ∂
#  (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(
#                       ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                         7/2            __________________
# }(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{
#
#             ⎞             3                    3
# t, x, y, ω))⎟      {V_{u}} (t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}}(t, x, y)⋅
#             ⎠
# ──────────────── + ───────────────────────────────────────────────────────────
#       2                         7/2            __________________
# u,xy}} (t, x, y)         {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t
#
#            ⎛                              ∂                                ⎞ ∂
# Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅─
#            ⎝                              ∂x                               ⎠ ∂
# ──────────────────────────────────────────────────────────────────────────────
#                                      7/2            __________________
# , x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,x
#
#                              3                    2                    2
# ─({V_{v}}(t, x, y))   {V_{u}} (t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,xy}} (t, x,
# x
# ─────────────────── - ────────────────────────────────────────────────────────
#    2                                7/2            __________________
# y}} (t, x, y)                {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx
#
#                ⎛                              ∂
#  y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω)
#                ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                          7/2            __________________
# }}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_
#
#  ⎞ ∂                             3                    2
# )⎟⋅──({V_{v}}(t, x, y))   {V_{u}} (t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,xy}}(t,
#  ⎠ ∂x
# ─────────────────────── + ────────────────────────────────────────────────────
#        2                                         7/2            ______________
# {u,xy}} (t, x, y)                         {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x,
#
#                                       ⎛                              ∂
#  x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\vare
#                                       ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
# ____                                                  7/2            _________
#  y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(
#
#                         ⎞ ∂                             3                    2
# psilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {V_{u}} (t, x, y)⋅{s_{u,xx}}
#                         ⎠ ∂y
# ────────────────────────────────────────────── + ─────────────────────────────
# _________           2                                                   7/2
# t, x, y) ⋅{s_{u,xy}} (t, x, y)                                   {V_{u}}   (t,
#
#                                                              ⎛
# (t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}
#                                                              ⎝
# ──────────────────────────────────────────────────────────────────────────────
#          __________________                                                  7
#  x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}
#
#               ∂                                ⎞ ∂
# }(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {V_{u}
#               ∂y                               ⎠ ∂x
# ───────────────────────────────────────────────────────────────────── - ──────
# /2            __________________           2
#   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#  3                                        3                     ⎛
# } (t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_
#                                                                 ⎝
# ──────────────────────────────────────────────────────────────────────────────
#        7/2            __________________
# {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x,
#
#                  ∂                                ⎞ ∂
# {v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {V_
#                  ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────── - ───
#             7/2            __________________           2
# y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#     3                                        3                     ⎛
# {u}} (t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsil
#                                                                    ⎝
# ──────────────────────────────────────────────────────────────────────────────
#           7/2            __________________
#    {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t,
#
#                     ∂                                ⎞ ∂
# on_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))
#                     ∂y                               ⎠ ∂x
# ─────────────────────────────────────────────────────────────────────────── +
#                7/2            __________________           2
# x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#        3                                        2
# {V_{u}} (t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅{s_{u,yy}}(t, x, y)
#
# ──────────────────────────────────────────────────────────────────────────────
#                        7/2            __________________
#                 {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{
#
#             ⎛                              ∂                                ⎞
# ⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅
#             ⎝                              ∂y                               ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                             7/2            __________________           2
# s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x
#
# ∂                                 3                    4                     ⎛
# ──({V_{v}}(t, x, y))       {V_{u}} (t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜
# ∂y                                                                           ⎝
# ──────────────────── - ───────────────────────────────────────────────────────
#                               7/2            __________________
# , y)                   {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t,
#
#                               ∂                                ⎞ ∂
# {\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t,
#                               ∂y                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                    7/2            __________________
# x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}
#
#                      2                                     3
#  x, y))       {V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy
#
# ─────────── - ────────────────────────────────────────────────────────────────
#  2                                  7/2            __________________
# } (t, x, y)                  {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx
#
#                        ⎛                              ∂
# }}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t,
#                        ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                          7/2            __________________
# }}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_
#
#          ⎞ ∂                             2
# x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}
#          ⎠ ∂x
# ─────────────────────────────── + ────────────────────────────────────────────
#        2                                                7/2            _______
# {u,xy}} (t, x, y)                                {V_{u}}   (t, x, y)⋅╲╱ {V_{v}
#
#  2                    2                     ⎛                              ∂
# } (t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──(
#                                             ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
# ___________                                                  7/2            __
# }(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {
#
#                               ⎞ ∂                             2
# {\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {V_{u}} (t, x, y)⋅{V_{v
#                               ⎠ ∂x
# ──────────────────────────────────────────────────── - ───────────────────────
# ________________           2
# V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#                       2
# }}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expec
#
# ──────────────────────────────────────────────────────────────────────────────
#          7/2            __________________
#   {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x
#
#       ⎛                              ∂                                ⎞ ∂
# tation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_
#       ⎝                              ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#               7/2            __________________           2
# , y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#                         2                                     2
# {u}}(t, x, y))   {V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u
#
# ────────────── - ─────────────────────────────────────────────────────────────
#                                                  7/2            ______________
#                                           {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x,
#
#                                               ⎛                              ∂
# ,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅─
#                                               ⎝                              ∂
# ──────────────────────────────────────────────────────────────────────────────
# ____                                                  7/2            _________
#  y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(
#
#                                 ⎞ ∂                             2
# ─({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {V_{u}} (t, x, y)⋅{V_
# y                               ⎠ ∂x
# ────────────────────────────────────────────────────── + ─────────────────────
# _________           2
# t, x, y) ⋅{s_{u,xy}} (t, x, y)                                          {V_{u}
#
#                                             3                     ⎛
# {v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilo
#                                                                   ⎝
# ──────────────────────────────────────────────────────────────────────────────
#  7/2            __________________
# }   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {
#
#                    ∂                                ⎞ ∂
# n_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {
#                    ∂x                               ⎠ ∂y
# ────────────────────────────────────────────────────────────────────────── + ─
#       7/2            __________________           2
# V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#       2                                                         3
# V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Exp
#
# ──────────────────────────────────────────────────────────────────────────────
#                      7/2            __________________
#               {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_
#
#         ⎛                              ∂                                ⎞ ∂
# ectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({
#         ⎝                              ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                           7/2            __________________           2
# {u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x,
#
#                           2
# V_{u}}(t, x, y))   {V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{
#
# ──────────────── - ───────────────────────────────────────────────────────────
#                                                    7/2            ____________
# y)                                          {V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t,
#
#       2                                         ⎛
# u,xy}} (t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)
#                                                 ⎝
# ──────────────────────────────────────────────────────────────────────────────
# ______                                                  7/2            _______
# x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}   (t, x, y)⋅╲╱ {V_{v}
#
#  ∂                                ⎞ ∂                             2
# ⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {V_{u}} (t, x, y)⋅{
#  ∂y                               ⎠ ∂y
# ──────────────────────────────────────────────────────── + ───────────────────
# ___________           2                                                7/2
# }(t, x, y) ⋅{s_{u,xy}} (t, x, y)                                {V_{u}}   (t,
#
#                           4                     ⎛
# V_{v}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)
#                                                 ⎝
# ──────────────────────────────────────────────────────────────────────────────
#         __________________                                                  7/
# x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - {V_{u}}
#
#  ∂                                ⎞ ∂
# ⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#  ∂y                               ⎠ ∂y
# ────────────────────────────────────────────────────────
# 2            __________________           2
#  (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#                                                                   5/2
# ∂                                           4⋅Vᵤᵥ(t, x, y)⋅{V_{u}}   (t, x, y)
# ──({s_{u,xy}}(t, x, y)) = - ──────────────────────────────────────────────────
# ∂t                                   7/2            __________________
#                             2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,x
#
#
#    __________________
# ⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x,
# ──────────────────────────────────────────────────────────────────────────────
#                                             7/2            __________________
# x}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅
#
#
#
#  y)                                                        4⋅Vᵤᵥ(t, x, y)⋅{V_{
# ──────────────────── + ───────────────────────────────────────────────────────
#           2                     7/2            __________________
# {s_{u,xy}} (t, x, y)   2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t
#
#
#    5/2            __________________           3
# u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
# ──────────────────────────────────────────────────────────────────────────────
#                                        7/2            __________________
# , x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u
#
#                            3                                     2
#                   4⋅{V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s
#
# ─────────────── + ────────────────────────────────────────────────────────────
#      2                                    7/2            __________________
# ,xy}} (t, x, y)                  2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s
#
#                                                  ⎛∂
# _{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y
#                                                  ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                                  7/2            ______________
# _{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x,
#
#       ∂                                ⎞            3
# , ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅{V_{u}} (t, x, y)⋅{V_{v}}(t, x, y
#       ∂x                               ⎠
# ──────────────────────────────────────── + ───────────────────────────────────
# ____           2                                          7/2            _____
#  y) ⋅{s_{u,xy}} (t, x, y)                        2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{
#
#             2                    2                     ⎛∂
# )⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t
#                                                        ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
# _____________                                                    7/2
# v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅
#
#             ∂                                ⎞            3
# , x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅{V_{u}} (t, x, y)⋅{V_{v}}(t
#             ∂y                               ⎠
# ────────────────────────────────────────────── + ─────────────────────────────
#   __________________           2                                7/2
# ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)              2⋅{V_{u}}   (t, x, y)⋅╲
#
#                   2                    2                     ⎛∂
# , x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜──({\varepsilon_
#                                                              ⎝∂y
# ──────────────────────────────────────────────────────────────────────────────
#  __________________                                                    7/2
# ╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t,
#
#                   ∂                                ⎞            3
# {u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   4⋅{V_{u}} (t, x, y)⋅{V_
#                   ∂x                               ⎠
# ──────────────────────────────────────────────────── - ───────────────────────
#         __________________           2                               7/2
# x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)             2⋅{V_{u}}   (t, x,
#
#                                             3                     ⎛∂
# {v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜──({\vareps
#                                                                   ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#       __________________                                                    7/
#  y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}
#
#                        ∂                                ⎞            3
# ilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   4⋅{V_{u}} (t, x, y
#                        ∂x                               ⎠
# ───────────────────────────────────────────────────────── + ──────────────────
# 2            __________________           2
#  (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)                       2⋅{
#
#                                                                      2
# )⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}} (t, x, y
#
# ──────────────────────────────────────────────────────────────────────────────
#       7/2            __________________
# V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y
#
#              ⎛∂                                 ∂
# )⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y,
#              ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#              7/2            __________________           2
# ) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#    ⎞                 3                                     4
# ω))⎟        2⋅{V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectat
#    ⎠
# ──── - ───────────────────────────────────────────────────────────────────────
#                 7/2            __________________
#        2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy
#
#    ⎛∂                                 ∂                                ⎞
# ion⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟
#    ⎝∂x                                ∂y                               ⎠
# ─────────────────────────────────────────────────────────────────────────────
#                        7/2            __________________           2
# }}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#                 3                                     4                     ⎛∂
#        2⋅{V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜─
#                                                                             ⎝∂
# - ────────────────────────────────────────────────────────────────────────────
#            7/2            __________________
#   2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t,
#
#                                  ∂                                ⎞
# ─({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟        4⋅{
# y                                ∂x                               ⎠
# ──────────────────────────────────────────────────────────────────────── - ───
#                   7/2            __________________           2
#  x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#       3                                     3
# V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Exp
#
# ──────────────────────────────────────────────────────────────────────────────
#            7/2            __________________
#   2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t,
#
#         ⎛∂                                 ∂                                ⎞
# ectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟
#         ⎝∂y                                ∂y                               ⎠
# ─────────────────────────────────────────────────────────────────────────────
#                   7/2            __________________           2
#  x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#            3                    2
#   2⋅{V_{u}} (t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x
#
# + ────────────────────────────────────────────────────────────────────────────
#                           7/2            __________________
#                  2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y
#
#                 ⎛                              ∂
# , y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω
#                 ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                  7/2            __________________           2
# )⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}}
#
#   ⎞ ∂                             3                    2                    2
# ))⎟⋅──({V_{v}}(t, x, y))   {V_{u}} (t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}} (
#   ⎠ ∂x
# ──────────────────────── + ───────────────────────────────────────────────────
#                                          7/2            __________________
# (t, x, y)                       2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_
#
#                     ⎛                              ∂
# t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x,
#                     ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                                 7/2            _______________
# {u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x,
#
#       ⎞ ∂                             3                    2
# y, ω))⎟⋅──({V_{v}}(t, x, y))   {V_{u}} (t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy
#       ⎠ ∂y
# ──────────────────────────── + ───────────────────────────────────────────────
# ___           2                              7/2            __________________
# y) ⋅{s_{u,xy}} (t, x, y)            2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y)
#
#   2                     ⎛                              ∂
# }} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t,
#                         ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                                     7/2            ___________
# ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t,
#
#           ⎞ ∂                               3
#  x, y, ω))⎟⋅──({V_{v}}(t, x, y))   2⋅{V_{u}} (t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_
#           ⎠ ∂x
# ──────────────────────────────── - ───────────────────────────────────────────
# _______           2                              7/2            ______________
#  x, y) ⋅{s_{u,xy}} (t, x, y)            2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x,
#
#        3                     ⎛                              ∂
# {u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u
#                              ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
# ____                                                    7/2            _______
#  y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}
#
#                ⎞ ∂                               3
# }}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   2⋅{V_{u}} (t, x, y)⋅{s_{u,xx}}(t, x, y
#                ⎠ ∂x
# ───────────────────────────────────── + ──────────────────────────────────────
# ___________           2                                         7/2
# }(t, x, y) ⋅{s_{u,xy}} (t, x, y)                       2⋅{V_{u}}   (t, x, y)⋅╲
#
#                                 2                     ⎛
# )⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x,
#                                                       ⎝
# ──────────────────────────────────────────────────────────────────────────────
#  __________________                                                    7/2
# ╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t,
#
#        ∂                                ⎞ ∂
#  y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))         {V_{u}}
#        ∂y                               ⎠ ∂y
# ────────────────────────────────────────────────────────────── - ─────────────
#         __________________           2                                    7/2
# x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)                  2⋅{V_{u}}   (
#
# 3                    4                     ⎛                              ∂
#  (t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({
#                                            ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#            __________________
# t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{
#
#                              ⎞ ∂                                         3
# \varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))               {V_{u}} (t,
#                              ⎠ ∂y
# ───────────────────────────────────────────────────────── - ──────────────────
#    7/2            __________________           2                     7/2
# u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)   2⋅{V_{u}}   (t, x,
#
#                 4                     ⎛                              ∂
# x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\vare
#                                       ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#       __________________                                                    7/
#  y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}
#
#                         ⎞ ∂                                     3
# psilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))         2⋅{V_{u}} (t, x, y)⋅{s_
#                         ⎠ ∂x
# ──────────────────────────────────────────────────── - ───────────────────────
# 2            __________________           2                          7/2
#  (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)        2⋅{V_{u}}   (t, x,
#
#        3                                         ⎛
# {u,xy}} (t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω
#                                                  ⎝
# ──────────────────────────────────────────────────────────────────────────────
#       __________________                                                    7/
#  y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}
#
#   ∂                                ⎞ ∂                               2
# )⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   2⋅{V_{u}} (t, x, y
#   ∂y                               ⎠ ∂y
# ───────────────────────────────────────────────────────── - ──────────────────
# 2            __________________           2
#  (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#                              2
# )⋅{V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y
#
# ──────────────────────────────────────────────────────────────────────────────
#                7/2            __________________
#       2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}
#
#              ⎛                              ∂                                ⎞
# )⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟
#              ⎝                              ∂x                               ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                       7/2            __________________           2
# }(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#  ∂                             2                                     2
# ⋅──({V_{u}}(t, x, y))   {V_{u}} (t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x, y
#  ∂x
# ───────────────────── - ──────────────────────────────────────────────────────
#                                               7/2            _________________
#                                      2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y)
#
#             2                     ⎛                              ∂
# )⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsil
#                                   ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
# _                                                    7/2            __________
#  ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t
#
#                     ⎞ ∂                             2
# on_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {V_{u}} (t, x, y)⋅{V_{v}}(t, x, y
#                     ⎠ ∂y
# ────────────────────────────────────────── - ─────────────────────────────────
# ________           2                                               7/2
# , x, y) ⋅{s_{u,xy}} (t, x, y)                             2⋅{V_{u}}   (t, x, y
#
#             2                    2                     ⎛
# )⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x
#                                                        ⎝
# ...
#
#                 ⎛                              ∂
# , y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω
#                 ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                     3/2
#              {V_{v}}   (t, x, y)
#
#   ⎞ ∂
# ))⎟⋅──({V_{v}}(t, x, y))   {s_{v,xx}}(t, x, y)⋅{s_{v,xy}}(t, x, y)⋅Expectation
#   ⎠ ∂y
# ──────────────────────── - ───────────────────────────────────────────────────
#                                                                              _
#                                                                            ╲╱
#
# ⎛                              ∂                                ⎞ ∂
# ⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t
# ⎝                              ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
# _________________   __________________
# {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                               ⎛
# , x, y))   {s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u
#                                                               ⎝
# ──────── - ───────────────────────────────────────────────────────────────────
#                                                               ________________
#                                                           2⋅╲╱ {V_{u}}(t, x, y
#
#                ∂                                ⎞ ∂
# }}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {s_{v
#                ∂x                               ⎠ ∂y
# ────────────────────────────────────────────────────────────────────── - ─────
# __   __________________
# ) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                               ⎛                              ∂
# ,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅─
#                                               ⎝                              ∂
# ──────────────────────────────────────────────────────────────────────────────
#                                               __________________   ___________
#                                           2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t,
#
#                                 ⎞ ∂                                2
# ─({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {s_{v,xy}} (t, x, y)⋅
# y                               ⎠ ∂x
# ────────────────────────────────────────────────────── - ─────────────────────
# _______
#  x, y)
#
#            ⎛                              ∂                                ⎞ ∂
# Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅─
#            ⎝                              ∂x                               ⎠ ∂
# ──────────────────────────────────────────────────────────────────────────────
#                     __________________   __________________
#                 2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                 2                     ⎛
# ─({V_{u}}(t, x, y))   {s_{v,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x,
# y                                                     ⎝
# ─────────────────── - ────────────────────────────────────────────────────────
#                                                                _______________
#                                                            2⋅╲╱ {V_{u}}(t, x,
#
#        ∂                                ⎞ ∂
#  y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {s_{v,xy}}(t,
#        ∂y                               ⎠ ∂x
# ────────────────────────────────────────────────────────────── - ─────────────
# ___   __________________
# y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                       ⎛                              ∂
#  x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\vare
#                                       ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                      __________________   __________________
#                                    ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                         ⎞ ∂
# psilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                         ⎠ ∂y
# ──────────────────────────────────────────────
#                                                                    ___________
#                                                                2⋅╲╱ {V_{u}}(t,
# ∂                         2⋅Vᵤᵥ(t, x, y)⋅{s_{v,yy}}(t, x, y)
# ──({s_{v,yy}}(t, x, y)) = ────────────────────────────────── - ───────────────
# ∂t                                 {V_{v}}(t, x, y)
#
#
# _______           2                     ⎛∂                                 ∂
#  x, y) ⋅{s_{v,xy}} (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──(
#                                         ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                        __________________
#                                      ╲╱ {V_{v}}(t, x, y)
#
#                               ⎞       __________________
# {\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{u}}(t, x, y) ⋅{s_{v,xy}}(t, x, y)⋅{
#                               ⎠
# ─────────────────────────────── - ────────────────────────────────────────────
#
#
#
#                               ⎛∂                                 ∂
# s_{v,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsil
#                               ⎝∂x                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                     __________________
#                   ╲╱ {V_{v}}(t, x, y)
#
#                     ⎞       __________________
# on_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{u}}(t, x, y) ⋅{s_{v,xy}}(t, x, y)⋅{s_{v,yy}}(
#                     ⎠
# ───────────────────── - ──────────────────────────────────────────────────────
#
#
#
#                     ⎛∂                                 ∂
# t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                     ⎝∂y                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#           __________________
#         ╲╱ {V_{v}}(t, x, y)
#
#           ⎞       __________________           2                     ⎛∂
#  x, y, ω))⎟   2⋅╲╱ {V_{u}}(t, x, y) ⋅{s_{v,yy}} (t, x, y)⋅Expectation⎜──({\var
#           ⎠                                                          ⎝∂y
# ─────────── - ────────────────────────────────────────────────────────────────
#                                                                     __________
#                                                                   ╲╱ {V_{v}}(t
#
#                           ∂                                ⎞     _____________
# epsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   ╲╱ {V_{u}}(t, x
#                           ∂y                               ⎠
# ──────────────────────────────────────────────────────────── + ───────────────
# ________
# , x, y)
#
# _____           2                     ⎛                              ∂
# , y) ⋅{s_{v,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\vare
#                                       ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                                     3/2
#                                              {V_{v}}   (t, x, y)
#
#                         ⎞ ∂                        __________________
# psilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{u}}(t, x, y) ⋅{s_{v,xy
#                         ⎠ ∂x
# ────────────────────────────────────────────── + ─────────────────────────────
#
#
#
#                                            ⎛                              ∂
# }}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({
#                                            ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                                3/2
#                                         {V_{v}}   (t, x, y)
#
#                              ⎞ ∂                        __________________
# \varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{u}}(t, x, y) ⋅{s_
#                              ⎠ ∂y
# ─────────────────────────────────────────────────── + ────────────────────────
#
#
#
#                                                 ⎛
# {v,xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)
#                                                 ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                     3/2
#                                              {V_{v}}   (t, x, y)
#
#  ∂                                ⎞ ∂                        _________________
# ⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{u}}(t, x, y)
#  ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────── + ───────────────────
#
#
#
# _           2                     ⎛                              ∂
#  ⋅{s_{v,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsil
#                                   ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                                 3/2
#                                          {V_{v}}   (t, x, y)
#
#                     ⎞ ∂                                2                     ⎛
# on_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {s_{v,xy}} (t, x, y)⋅Expectation⎜
#                     ⎠ ∂y                                                     ⎝
# ────────────────────────────────────────── - ─────────────────────────────────
#
#
#
#                               ∂                                ⎞ ∂
# {\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t,
#                               ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#        __________________   __________________
#      ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                              ⎛
#  x, y))   {s_{v,xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}
#                                                              ⎝
# ─────── - ────────────────────────────────────────────────────────────────────
#                                                             __________________
#                                                           ╲╱ {V_{u}}(t, x, y)
#
#               ∂                                ⎞ ∂
# }(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {s_{v,
#               ∂x                               ⎠ ∂y
# ───────────────────────────────────────────────────────────────────── - ──────
#    __________________
# ⋅╲╱ {V_{v}}(t, x, y)
#
#                                              ⎛                              ∂
# xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──
#                                              ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                             __________________   _____________
#                                           ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x
#
#                                ⎞ ∂                                2
# ({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {s_{v,yy}} (t, x, y)⋅E
#                                ⎠ ∂x
# ───────────────────────────────────────────────────── - ──────────────────────
# _____
# , y)
#
#           ⎛                              ∂                                ⎞ ∂
# xpectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──
#           ⎝                              ∂y                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                   __________________   __________________
#                 ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#
# ({V_{u}}(t, x, y))
#
# ──────────────────
