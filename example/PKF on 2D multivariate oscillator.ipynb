# %% [markdown]
# O. Pannekoucke$^{1,2,3}$
#
# $^1$ INPT-ENM, Toulouse, France
#
# $^2$ CNRM, Université de Toulouse, Météo-France, CNRS, Toulouse, France
#
# $^3$ CERFACS, Toulouse, France
#
# (olivier.pannekoucke@meteo.fr)

# %% [markdown]
# **Abstract**
#
# This notebook illustrates the use of sympkf to build and handle the PKF dynamics associated with the harmonic oscillator as 2D fields given by
# $$\left\{\begin{array}{c}
# \partial_t u =-v\\
# \partial_t v =u
# \end{array}\right.$$
# where $u$ and $v$ are functions of $t,x,y$.
# For this dynamics, the resulting PKF system is not closed because of the cros-correlation.

# %% [markdown]
# # Definition of the 2D multivariate dynamics

# %%
import sympy
sympy.init_printing()

# %% [markdown]
# **Definition of the dynamics from sympy tools**

# %%
from sympy import Function, Derivative, Eq, symbols
from sympkf import SymbolicPKF

# %%
t, x, y  = symbols('t x y')
u = Function('u')(t,x,y)
v = Function('v')(t,x,y)
dynamics = [Eq(Derivative(u,t), -v), Eq(Derivative(v,t), u)]
dynamics
# Out:
# ⎡∂                             ∂                          ⎤
# ⎢──(u(t, x, y)) = -v(t, x, y), ──(v(t, x, y)) = u(t, x, y)⎥
# ⎣∂t                            ∂t                         ⎦

# %% [markdown]
# # Computation of the PKF dynamics by using SymPKF

# %%
pkf_dynamics = SymbolicPKF(dynamics)

# %%
for equation in pkf_dynamics.in_metric:    display(equation)
# Out:
# ∂
# ──(u(t, x, y)) = -v(t, x, y)
# ∂t
# ∂
# ──(v(t, x, y)) = u(t, x, y)
# ∂t
# ∂                           __________________   __________________
# ──({V_{u}}(t, x, y)) = -2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y) ⋅Expectatio
# ∂t
#
#
# n({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
# ∂                          __________________   __________________
# ──({V_{v}}(t, x, y)) = 2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y) ⋅Expectation
# ∂t
#
#
# ({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
#
#                               __________________
# ∂                         2⋅╲╱ {V_{v}}(t, x, y) ⋅{g_{u,xx}}(t, x, y)⋅Expectati
# ──({g_{u,xx}}(t, x, y)) = ────────────────────────────────────────────────────
# ∂t                                                                          __
#                                                                           ╲╱ {
#
#                                                                       ________
#                                                                   2⋅╲╱ {V_{v}}
# on({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
# ─────────────────────────────────────────────────────────────── - ────────────
# ________________
# V_{u}}(t, x, y)
#
# __________            ⎛∂                                 ∂
# (t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(
#                       ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                 __________________
#                               ╲╱ {V_{u}}(t, x, y)
#
#             ⎞              ⎛                              ∂
# t, x, y, ω))⎟   Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}
#             ⎠              ⎝                              ∂x
# ───────────── - ──────────────────────────────────────────────────────────────
#                                               __________________   ___________
#                                             ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t,
#
#              ⎞ ∂                        __________________            ⎛
# (t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜{\varep
#              ⎠ ∂x                                                     ⎝
# ─────────────────────────────────── + ────────────────────────────────────────
# _______
#  x, y)
#
#                        ∂                                ⎞ ∂
# silon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                        ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                 3/2
#          {V_{u}}   (t, x, y)
#
#                               __________________
# ∂                         2⋅╲╱ {V_{v}}(t, x, y) ⋅{g_{u,xy}}(t, x, y)⋅Expectati
# ──({g_{u,xy}}(t, x, y)) = ────────────────────────────────────────────────────
# ∂t                                                                          __
#                                                                           ╲╱ {
#
#                                                                     __________
#                                                                   ╲╱ {V_{v}}(t
# on({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
# ─────────────────────────────────────────────────────────────── - ────────────
# ________________
# V_{u}}(t, x, y)
#
# ________            ⎛∂                                 ∂
# , x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                     ⎝∂x                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                __________________
#                              ╲╱ {V_{u}}(t, x, y)
#
#           ⎞     __________________            ⎛∂
#  x, y, ω))⎟   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω
#           ⎠                                   ⎝∂y
# ─────────── - ────────────────────────────────────────────────────────────────
#                                                          __________________
#                                                        ╲╱ {V_{u}}(t, x, y)
#
#    ∂                                ⎞              ⎛
# ))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   Expectation⎜{\varepsilon_{v}}(t, x, y,
#    ∂x                               ⎠              ⎝
# ───────────────────────────────────── - ──────────────────────────────────────
#                                                                        _______
#                                                                    2⋅╲╱ {V_{u}
#
#     ∂                                ⎞ ∂                                 ⎛
#  ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\va
#     ∂x                               ⎠ ∂y                                ⎝
# ─────────────────────────────────────────────────────────── - ────────────────
# ___________   __________________
# }(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                           ∂                                ⎞ ∂
# repsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x,
#                           ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                __________________   __________________
#            2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#         __________________            ⎛                              ∂
# y))   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\vare
#                                       ⎝                              ∂x
# ─── + ────────────────────────────────────────────────────────────────────────
#                                                                3/2
#                                                       2⋅{V_{u}}   (t, x, y)
#
#                         ⎞ ∂                        __________________
# psilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅Expectat
#                         ⎠ ∂y
# ────────────────────────────────────────────── + ─────────────────────────────
#
#
#
#    ⎛                              ∂                                ⎞ ∂
# ion⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}
#    ⎝                              ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                             3/2
#                    2⋅{V_{u}}   (t, x, y)
#
#
# }(t, x, y))
#
# ───────────
#
#                               __________________
# ∂                         2⋅╲╱ {V_{v}}(t, x, y) ⋅{g_{u,yy}}(t, x, y)⋅Expectati
# ──({g_{u,yy}}(t, x, y)) = ────────────────────────────────────────────────────
# ∂t                                                                          __
#                                                                           ╲╱ {
#
#                                                                       ________
#                                                                   2⋅╲╱ {V_{v}}
# on({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
# ─────────────────────────────────────────────────────────────── - ────────────
# ________________
# V_{u}}(t, x, y)
#
# __________            ⎛∂                                 ∂
# (t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(
#                       ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                 __________________
#                               ╲╱ {V_{u}}(t, x, y)
#
#             ⎞              ⎛                              ∂
# t, x, y, ω))⎟   Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}
#             ⎠              ⎝                              ∂y
# ───────────── - ──────────────────────────────────────────────────────────────
#                                               __________________   ___________
#                                             ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t,
#
#              ⎞ ∂                        __________________            ⎛
# (t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅Expectation⎜{\varep
#              ⎠ ∂y                                                     ⎝
# ─────────────────────────────────── + ────────────────────────────────────────
# _______
#  x, y)
#
#                        ∂                                ⎞ ∂
# silon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                        ∂y                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                 3/2
#          {V_{u}}   (t, x, y)
#
#                                 __________________
# ∂                           2⋅╲╱ {V_{u}}(t, x, y) ⋅{g_{v,xx}}(t, x, y)⋅Expecta
# ──({g_{v,xx}}(t, x, y)) = - ──────────────────────────────────────────────────
# ∂t
#                                                                             ╲╱
#
#                                                                         ______
#                                                                     2⋅╲╱ {V_{u
# tion({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
# ───────────────────────────────────────────────────────────────── + ──────────
# __________________
#  {V_{v}}(t, x, y)
#
# ____________            ⎛∂                                 ∂
# }}(t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}
#                         ⎝∂x                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                   __________________
#                                 ╲╱ {V_{v}}(t, x, y)
#
#               ⎞     __________________            ⎛
# }(t, x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\varepsilon_{u}}(t, x, y,
#               ⎠                                   ⎝
# ─────────────── - ────────────────────────────────────────────────────────────
#                                                                           3/2
#                                                                    {V_{v}}   (
#
#    ∂                                ⎞ ∂                                 ⎛
# ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\var
#    ∂x                               ⎠ ∂x                                ⎝
# ────────────────────────────────────────────────────────── + ─────────────────
#
# t, x, y)
#
#                          ∂                                ⎞ ∂
# epsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y
#                          ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#              __________________   __________________
#            ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#
# ))
#
# ──
#
#                                 __________________
# ∂                           2⋅╲╱ {V_{u}}(t, x, y) ⋅{g_{v,xy}}(t, x, y)⋅Expecta
# ──({g_{v,xy}}(t, x, y)) = - ──────────────────────────────────────────────────
# ∂t
#                                                                             ╲╱
#
#                                                                       ________
#                                                                     ╲╱ {V_{u}}
# tion({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
# ───────────────────────────────────────────────────────────────── + ──────────
# __________________
#  {V_{v}}(t, x, y)
#
# __________            ⎛∂                                 ∂
# (t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(
#                       ⎝∂x                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                  __________________
#                                ╲╱ {V_{v}}(t, x, y)
#
#             ⎞     __________________            ⎛∂
# t, x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y,
#             ⎠                                   ⎝∂y
# ───────────── + ──────────────────────────────────────────────────────────────
#                                                            __________________
#                                                          ╲╱ {V_{v}}(t, x, y)
#
#      ∂                                ⎞     __________________            ⎛
#  ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\v
#      ∂x                               ⎠                                   ⎝
# ─────────────────────────────────────── - ────────────────────────────────────
#
#
#
#                            ∂                                ⎞ ∂
# arepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x,
#                            ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                      3/2
#             2⋅{V_{v}}   (t, x, y)
#
#          __________________            ⎛                              ∂
#  y))   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\var
#                                        ⎝                              ∂y
# ──── - ───────────────────────────────────────────────────────────────────────
#                                                                 3/2
#                                                        2⋅{V_{v}}   (t, x, y)
#
#                          ⎞ ∂                                 ⎛
# epsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\varepsilon_{u}
#                          ⎠ ∂x                                ⎝
# ─────────────────────────────────────────────── + ────────────────────────────
#
#                                                                              2
#
#               ∂                                ⎞ ∂
# }(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   Expect
#               ∂x                               ⎠ ∂y
# ───────────────────────────────────────────────────────────────────── + ──────
#    __________________   __________________
# ⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#      ⎛                              ∂                                ⎞ ∂
# ation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{
#      ⎝                              ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                          __________________   __________________
#                      2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#
# u}}(t, x, y))
#
# ─────────────
#
#                                 __________________
# ∂                           2⋅╲╱ {V_{u}}(t, x, y) ⋅{g_{v,yy}}(t, x, y)⋅Expecta
# ──({g_{v,yy}}(t, x, y)) = - ──────────────────────────────────────────────────
# ∂t
#                                                                             ╲╱
#
#                                                                         ______
#                                                                     2⋅╲╱ {V_{u
# tion({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
# ───────────────────────────────────────────────────────────────── + ──────────
# __________________
#  {V_{v}}(t, x, y)
#
# ____________            ⎛∂                                 ∂
# }}(t, x, y) ⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}
#                         ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                   __________________
#                                 ╲╱ {V_{v}}(t, x, y)
#
#               ⎞     __________________            ⎛
# }(t, x, y, ω))⎟   ╲╱ {V_{u}}(t, x, y) ⋅Expectation⎜{\varepsilon_{u}}(t, x, y,
#               ⎠                                   ⎝
# ─────────────── - ────────────────────────────────────────────────────────────
#                                                                           3/2
#                                                                    {V_{v}}   (
#
#    ∂                                ⎞ ∂                                 ⎛
# ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   Expectation⎜{\var
#    ∂y                               ⎠ ∂y                                ⎝
# ────────────────────────────────────────────────────────── + ─────────────────
#
# t, x, y)
#
#                          ∂                                ⎞ ∂
# epsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y
#                          ∂y                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#              __________________   __________________
#            ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#
# ))
#
# ──

# %%
for equation in pkf_dynamics.in_aspect:    display(equation)
# Out:
# ∂
# ──(u(t, x, y)) = -v(t, x, y)
# ∂t
# ∂
# ──(v(t, x, y)) = u(t, x, y)
# ∂t
# ∂                           __________________   __________________
# ──({V_{u}}(t, x, y)) = -2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y) ⋅Expectatio
# ∂t
#
#
# n({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
# ∂                          __________________   __________________
# ──({V_{v}}(t, x, y)) = 2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y) ⋅Expectation
# ∂t
#
#
# ({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
#                               __________________           2
#                           2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}} (t, x, y)⋅Expectat
# ∂
# ──({s_{u,xx}}(t, x, y)) = ────────────────────────────────────────────────────
# ∂t
#
#
#    ⎛∂                                 ∂                                ⎞
# ion⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲
#    ⎝∂x                                ∂x                               ⎠
# ──────────────────────────────────────────────────────────────────────── + ───
#   __________________
# ╲╱ {V_{u}}(t, x, y)
#
#  __________________                                                    ⎛∂
# ╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅Expectation⎜──({\v
#                                                                        ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                                              _________________
#                                                            ╲╱ {V_{u}}(t, x, y)
#
#                             ∂                                ⎞       _________
# arepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{v}}(
#                             ∂y                               ⎠
# ────────────────────────────────────────────────────────────── + ─────────────
# _
#
#
# _________                                                    ⎛∂
# t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅Expectation⎜──({\varepsilon_
#                                                              ⎝∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                                    __________________
#                                                  ╲╱ {V_{u}}(t, x, y)
#
#                   ∂                                ⎞
# {u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟       __________________
#                   ∂x                               ⎠   2⋅╲╱ {V_{v}}(t, x, y) ⋅
# ──────────────────────────────────────────────────── - ───────────────────────
#
#
#
#
#
# {s_{u,xx}}(t, x, y)⋅Expectation({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}
# ──────────────────────────────────────────────────────────────────────────────
#                            __________________
#                          ╲╱ {V_{u}}(t, x, y)
#
#                      __________________           2                     ⎛∂
#                  2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜──({\
# }(t, x, y, ω))                                                          ⎝∂y
# ────────────── + ─────────────────────────────────────────────────────────────
#                                                                        _______
#                                                                      ╲╱ {V_{u}
#
#                              ∂                                ⎞             2
# varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   {s_{u,xx}} (
#                              ∂y                               ⎠
# ─────────────────────────────────────────────────────────────── + ────────────
# ___________
# }(t, x, y)
#
#                     ⎛                              ∂
# t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x,
#                     ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                             __________________   __________________
#                           ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#       ⎞ ∂
# y, ω))⎟⋅──({V_{v}}(t, x, y))   {s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅Expecta
#       ⎠ ∂x
# ──────────────────────────── + ───────────────────────────────────────────────
#
#
#
#     ⎛                              ∂                                ⎞ ∂
# tion⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v
#     ⎝                              ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#    __________________   __________________
#  ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                                   ⎛
# }}(t, x, y))   {s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅Expectation⎜{\varepsilo
#                                                                   ⎝
# ──────────── + ───────────────────────────────────────────────────────────────
#                                                                  _____________
#                                                                ╲╱ {V_{u}}(t, x
#
#                    ∂                                ⎞ ∂
# n_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {
#                    ∂y                               ⎠ ∂x
# ────────────────────────────────────────────────────────────────────────── + ─
# _____   __________________
# , y) ⋅╲╱ {V_{v}}(t, x, y)
#
#          2                     ⎛                              ∂
# s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_
#                                ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                        __________________   __________________
#                                      ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                  ⎞ ∂                        __________________           2
# {u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}} (t,
#                  ⎠ ∂y
# ─────────────────────────────────────── - ────────────────────────────────────
#
#
#
#                  ⎛                              ∂
# x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y,
#                  ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                3/2
#                         {V_{u}}   (t, x, y)
#
#    ⎞ ∂                        __________________
# ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}
#    ⎠ ∂x
# ───────────────────────── - ──────────────────────────────────────────────────
#
#
#
#                       ⎛                              ∂
# }(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x
#                       ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                           3/2
#                    {V_{u}}   (t, x, y)
#
#         ⎞ ∂                        __________________
# , y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{
#         ⎠ ∂y
# ────────────────────────────── - ─────────────────────────────────────────────
#
#
#
#                            ⎛                              ∂
# u,xy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}
#                            ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                3/2
#                         {V_{u}}   (t, x, y)
#
#              ⎞ ∂                        __________________           2
# (t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y
#              ⎠ ∂x
# ─────────────────────────────────── - ────────────────────────────────────────
#
#
#
#              ⎛                              ∂                                ⎞
# )⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟
#              ⎝                              ∂y                               ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                            3/2
#                     {V_{u}}   (t, x, y)
#
#  ∂
# ⋅──({V_{u}}(t, x, y))
#  ∂y
# ─────────────────────
#                                                                         2
#                           4⋅{V_{u}}(t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x
# ∂
# ──({s_{u,xy}}(t, x, y)) = ────────────────────────────────────────────────────
# ∂t                                                3/2            _____________
#                                          2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x
#
#                                                         ⎛∂
# , y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(
#                                                         ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
# _____                                                    3/2            ______
# , y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v
#
#              ∂                                ⎞
# t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅{V_{u}}(t, x, y)⋅{V_{v}}(t
#              ∂x                               ⎠
# ─────────────────────────────────────────────── + ────────────────────────────
# ____________           2                                        3/2
# }}(t, x, y) ⋅{s_{u,xy}} (t, x, y)                      2⋅{V_{u}}   (t, x, y)⋅╲
#
#                   2                    2                     ⎛∂
# , x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜──({\varepsilon_
#                                                              ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#  __________________                                                    3/2
# ╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t,
#
#                   ∂                                ⎞
# {u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅{V_{u}}(t, x, y)⋅{V_{
#                   ∂y                               ⎠
# ──────────────────────────────────────────────────── + ───────────────────────
#         __________________           2                               3/2
# x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)             2⋅{V_{u}}   (t, x,
#
#                        2                    2                     ⎛∂
# v}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜──({\vareps
#                                                                   ⎝∂y
# ──────────────────────────────────────────────────────────────────────────────
#       __________________                                                    3/
#  y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}
#
#                        ∂                                ⎞
# ilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   4⋅{V_{u}}(t, x, y)
#                        ∂x                               ⎠
# ───────────────────────────────────────────────────────── - ──────────────────
# 2            __________________           2                               3/2
#  (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)             2⋅{V_{u}}   (
#
#                                                 3                     ⎛∂
# ⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜──({\va
#                                                                       ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#            __________________
# t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{
#
#                            ∂                                ⎞
# repsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   4⋅{V_{u}}(t, x
#                            ∂x                               ⎠
# ───────────────────────────────────────────────────────────── + ──────────────
#    3/2            __________________           2
# u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#                                                                         2
# , y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}} (t, x
#
# ──────────────────────────────────────────────────────────────────────────────
#           3/2            __________________
#  2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t,
#
#                 ⎛∂                                 ∂
# , y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x,
#                 ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                  3/2            __________________           2
# x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#       ⎞
# y, ω))⎟
#       ⎠   4⋅{V_{u}}(t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t
# ─────── - ────────────────────────────────────────────────────────────────────
#                              3/2            __________________
#                     2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x
#
#
#
# , x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation({\varepsilon_{u}}(t, x, y, ω)⋅{\vareps
# ──────────────────────────────────────────────────────────────────────────────
#                                     3/2            __________________
# , y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy
#
#                                                                             4
#                               2⋅{V_{u}}(t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xy}} (
# ilon_{v}}(t, x, y, ω))
# ────────────────────── - ─────────────────────────────────────────────────────
#   2                               3/2            __________________
# }} (t, x, y)             2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}
#
#                     ⎛∂                                 ∂
# t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t,
#                     ⎝∂x                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                          3/2            __________________
# (t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_
#
#           ⎞                                                            4
#  x, y, ω))⎟              2⋅{V_{u}}(t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xy}} (t, x,
#           ⎠
# ───────────────── - ──────────────────────────────────────────────────────────
#        2                     3/2            __________________
# {u,xy}} (t, x, y)   2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x
#
#                ⎛∂                                 ∂
#  y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y
#                ⎝∂y                                ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                     3/2            __________________
# , y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy
#
#      ⎞                                                       3
# , ω))⎟         4⋅{V_{u}}(t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅{s_{u,
#      ⎠
# ──────────── - ───────────────────────────────────────────────────────────────
#   2                          3/2            __________________
# }} (t, x, y)        2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x
#
#                          ⎛∂                                 ∂
# yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v
#                          ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                     3/2            __________________
# , y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy
#
#                ⎞
# }}(t, x, y, ω))⎟                                                          3
#                ⎠            4⋅{V_{u}}(t, x, y)⋅{V_{v}}(t, x, y)⋅{s_{u,xy}} (t,
# ──────────────── + ───────────────────────────────────────────────────────────
#   2                         3/2            __________________
# }} (t, x, y)       2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x,
#
#
#
#  x, y)⋅Expectation({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω)
# ──────────────────────────────────────────────────────────────────────────────
#                                    3/2            __________________
#  y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}
#
#                                            2
#               2⋅{V_{u}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{
# )
# ─────────── + ────────────────────────────────────────────────────────────────
#  2                                    3/2            __________________
# } (t, x, y)                  2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,
#
#                            ⎛                              ∂
# u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}
#                            ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                              3/2            __________________
# xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y)
#
#              ⎞ ∂                                                 2
# (t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {V_{u}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s
#              ⎠ ∂x
# ─────────────────────────────────── + ────────────────────────────────────────
#            2                                       3/2            ____________
# ⋅{s_{u,xy}} (t, x, y)                     2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t,
#
#         2                     ⎛                              ∂
# _{u,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{
#                               ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
# ______                                                    3/2            _____
# x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{
#
#                 ⎞ ∂                                                 2
# u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {V_{u}}(t, x, y)⋅{s_{u,xx}} (t, x, y)
#                 ⎠ ∂y
# ────────────────────────────────────── + ─────────────────────────────────────
# _____________           2                             3/2            _________
# v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)           2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(
#
#            2                     ⎛                              ∂
# ⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilo
#                                  ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
# _________                                                    3/2            __
# t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {
#
#                    ⎞ ∂
# n_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   2⋅{V_{u}}(t, x, y)⋅{s_{u,xx}}(t, x
#                    ⎠ ∂x
# ───────────────────────────────────────── - ──────────────────────────────────
# ________________           2                              3/2            _____
# V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)            2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{
#
#                3                     ⎛                              ∂
# , y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varep
#                                      ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
# _____________                                                    3/2
# v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅
#
#                        ⎞ ∂
# silon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   2⋅{V_{u}}(t, x, y)⋅{s_{u,xx}}(
#                        ⎠ ∂x
# ───────────────────────────────────────────── + ──────────────────────────────
#   __________________           2                                        3/2
# ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)                      2⋅{V_{u}}   (t,
#
#                                        2                     ⎛
# t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}
#                                                              ⎝
# ──────────────────────────────────────────────────────────────────────────────
#          __________________
#  x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}
#
#               ∂                                ⎞ ∂
# }(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))
#               ∂y                               ⎠ ∂y
# ───────────────────────────────────────────────────────────────────── - ──────
#  3/2            __________________           2
# }   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)                 2⋅{V_{
#
#                            4                     ⎛
# {V_{u}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω
#                                                  ⎝
# ──────────────────────────────────────────────────────────────────────────────
#    3/2            __________________
# u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) -
#
#   ∂                                ⎞ ∂
# )⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))                {V_{u
#   ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────── - ───────────
#           3/2            __________________           2                     3/
#  2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)   2⋅{V_{u}}
#
#                       4                     ⎛                              ∂
# }}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──(
#                                             ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
# 2            __________________
#  (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V
#
#                               ⎞ ∂
# {\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))          2⋅{V_{u}}(t, x,
#                               ⎠ ∂x
# ─────────────────────────────────────────────────────────── - ────────────────
#      3/2            __________________           2                          3/
# _{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)        2⋅{V_{u}}
#
#              3                                         ⎛
# y)⋅{s_{u,xy}} (t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x
#                                                        ⎝
# ──────────────────────────────────────────────────────────────────────────────
# 2            __________________
#  (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V
#
#         ∂                                ⎞ ∂
# , y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   2⋅{V_{v}}(t,
#         ∂y                               ⎠ ∂y
# ─────────────────────────────────────────────────────────────── - ────────────
#      3/2            __________________           2
# _{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#                  2
#  x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectatio
#
# ──────────────────────────────────────────────────────────────────────────────
#             3/2            __________________
#    2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t
#
#  ⎛                              ∂                                ⎞ ∂
# n⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(
#  ⎝                              ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                    3/2            __________________           2
# , x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#
#                                        2                    2
# t, x, y))   {V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}} (t, x, y)⋅Expecta
#
# ───────── - ──────────────────────────────────────────────────────────────────
#                          3/2            __________________
#                 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x, y)
#
#     ⎛                              ∂                                ⎞ ∂
# tion⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{u
#     ⎝                              ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                 3/2            __________________           2
# ⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (
#
#                                           2                    2
# }}(t, x, y))   {V_{v}}(t, x, y)⋅{s_{u,xx}} (t, x, y)⋅{s_{u,yy}} (t, x, y)⋅Expe
#
# ──────────── - ───────────────────────────────────────────────────────────────
#                             3/2            __________________
# t, x, y)           2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t, x,
#
#        ⎛                              ∂                                ⎞ ∂
# ctation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V
#        ⎝                              ∂y                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                    3/2            __________________
#  y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}
#
#                                                                    3
# _{u}}(t, x, y))   2⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅
#
# ─────────────── + ────────────────────────────────────────────────────────────
#  2                              3/2            __________________
# } (t, x, y)            2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xx}}(t
#
#            ⎛                              ∂                                ⎞ ∂
# Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅─
#            ⎝                              ∂x                               ⎠ ∂
# ──────────────────────────────────────────────────────────────────────────────
#                                        3/2            __________________
# , x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u
#
#
# ─({V_{u}}(t, x, y))   2⋅{V_{v}}(t, x, y)⋅{s_{u,xx}}(t, x, y)⋅{s_{u,xy}}(t, x,
# x
# ─────────────────── - ────────────────────────────────────────────────────────
#      2                                        3/2            _________________
# ,xy}} (t, x, y)                      2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x, y)
#
#              2                     ⎛                              ∂
# y)⋅{s_{u,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsi
#                                    ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
# _                                                    3/2            __________
#  ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t
#
#                      ⎞ ∂
# lon_{u}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))         {V_{v}}(t, x, y)⋅{s_{u,xy}
#                      ⎠ ∂y
# ─────────────────────────────────────────── + ────────────────────────────────
# ________           2                                   3/2            ________
# , x, y) ⋅{s_{u,xy}} (t, x, y)                 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}
#
#  4                     ⎛                              ∂
# } (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t,
#                        ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
# __________                                                    3/2            _
# (t, x, y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱
#
#          ⎞ ∂                                                              4
# x, y, ω))⎟⋅──({V_{u}}(t, x, y))                {V_{v}}(t, x, y)⋅{s_{u,xy}} (t,
#          ⎠ ∂y
# ────────────────────────────────────── + ─────────────────────────────────────
# _________________           2                     3/2            _____________
# {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)   2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x
#
#                   ⎛                              ∂
#  x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y,
#                   ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
# _____                                                    3/2            ______
# , y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v
#
#     ⎞ ∂                                                          3
#  ω))⎟⋅──({V_{u}}(t, x, y))          2⋅{V_{v}}(t, x, y)⋅{s_{u,xy}} (t, x, y)⋅{s
#     ⎠ ∂x
# ───────────────────────────────── + ──────────────────────────────────────────
# ____________           2                          3/2            _____________
# }}(t, x, y) ⋅{s_{u,xy}} (t, x, y)        2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v}}(t, x
#
#                              ⎛                              ∂
# _{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u
#                              ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
# _____                                                    3/2            ______
# , y) ⋅{s_{u,xx}}(t, x, y)⋅{s_{u,yy}}(t, x, y) - 2⋅{V_{u}}   (t, x, y)⋅╲╱ {V_{v
#
#                ⎞ ∂
# }}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                ⎠ ∂y
# ─────────────────────────────────────
# ____________           2
# }}(t, x, y) ⋅{s_{u,xy}} (t, x, y)
#                               __________________           2
#                           2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t, x, y)⋅Expectat
# ∂
# ──({s_{u,yy}}(t, x, y)) = ────────────────────────────────────────────────────
# ∂t
#
#
#    ⎛∂                                 ∂                                ⎞
# ion⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲
#    ⎝∂x                                ∂x                               ⎠
# ──────────────────────────────────────────────────────────────────────── + ───
#   __________________
# ╲╱ {V_{u}}(t, x, y)
#
#  __________________                                                    ⎛∂
# ╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜──({\v
#                                                                        ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                                              _________________
#                                                            ╲╱ {V_{u}}(t, x, y)
#
#                             ∂                                ⎞       _________
# arepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{v}}(
#                             ∂y                               ⎠
# ────────────────────────────────────────────────────────────── + ─────────────
# _
#
#
# _________                                                    ⎛∂
# t, x, y) ⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜──({\varepsilon_
#                                                              ⎝∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                                    __________________
#                                                  ╲╱ {V_{u}}(t, x, y)
#
#                   ∂                                ⎞       __________________
# {u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{v}}(t, x, y) ⋅
#                   ∂x                               ⎠
# ──────────────────────────────────────────────────── + ───────────────────────
#
#
#
#           2                     ⎛∂                                 ∂
# {s_{u,yy}} (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\vareps
#                                 ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                __________________
#                              ╲╱ {V_{u}}(t, x, y)
#
#                       ⎞
# ilon_{v}}(t, x, y, ω))⎟       __________________
#                       ⎠   2⋅╲╱ {V_{v}}(t, x, y) ⋅{s_{u,yy}}(t, x, y)⋅Expectati
# ─────────────────────── - ────────────────────────────────────────────────────
#                                                                             __
#                                                                           ╲╱ {
#
#                                                                             2
#                                                                   {s_{u,xy}} (
# on({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
# ─────────────────────────────────────────────────────────────── + ────────────
# ________________
# V_{u}}(t, x, y)
#
#                     ⎛                              ∂
# t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x,
#                     ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                             __________________   __________________
#                           ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#       ⎞ ∂
# y, ω))⎟⋅──({V_{v}}(t, x, y))   {s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expecta
#       ⎠ ∂x
# ──────────────────────────── + ───────────────────────────────────────────────
#
#
#
#     ⎛                              ∂                                ⎞ ∂
# tion⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v
#     ⎝                              ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────────────────────────────
#    __________________   __________________
#  ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                                   ⎛
# }}(t, x, y))   {s_{u,xy}}(t, x, y)⋅{s_{u,yy}}(t, x, y)⋅Expectation⎜{\varepsilo
#                                                                   ⎝
# ──────────── + ───────────────────────────────────────────────────────────────
#                                                                  _____________
#                                                                ╲╱ {V_{u}}(t, x
#
#                    ∂                                ⎞ ∂
# n_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {
#                    ∂y                               ⎠ ∂x
# ────────────────────────────────────────────────────────────────────────── + ─
# _____   __________________
# , y) ⋅╲╱ {V_{v}}(t, x, y)
#
#          2                     ⎛                              ∂
# s_{u,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_
#                                ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                        __________________   __________________
#                                      ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                  ⎞ ∂                        __________________           2
# {u}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}} (t,
#                  ⎠ ∂y
# ─────────────────────────────────────── - ────────────────────────────────────
#
#
#
#                  ⎛                              ∂
# x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x, y,
#                  ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                3/2
#                         {V_{u}}   (t, x, y)
#
#    ⎞ ∂                        __________________
# ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}}(t, x, y)⋅{s_{u,yy}
#    ⎠ ∂x
# ───────────────────────── - ──────────────────────────────────────────────────
#
#
#
#                       ⎛                              ∂
# }(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}(t, x
#                       ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                           3/2
#                    {V_{u}}   (t, x, y)
#
#         ⎞ ∂                        __________________
# , y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,xy}}(t, x, y)⋅{s_{
#         ⎠ ∂y
# ────────────────────────────── - ─────────────────────────────────────────────
#
#
#
#                            ⎛                              ∂
# u,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{v}}(t, x, y, ω)⋅──({\varepsilon_{u}}
#                            ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                3/2
#                         {V_{u}}   (t, x, y)
#
#              ⎞ ∂                        __________________           2
# (t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   ╲╱ {V_{v}}(t, x, y) ⋅{s_{u,yy}} (t, x, y
#              ⎠ ∂x
# ...
#  y, ω))⎟⋅──({V_{v}}(t, x, y))   {s_{v,xx}}(t, x, y)⋅{s_{v,xy}}(t, x, y)⋅Expect
#        ⎠ ∂y
# ───────────────────────────── - ──────────────────────────────────────────────
#
#
#
#      ⎛                              ∂                                ⎞ ∂
# ation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{
#      ⎝                              ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#     __________________   __________________
#   ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                                    ⎛
# u}}(t, x, y))   {s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsil
#                                                                    ⎝
# ───────────── - ──────────────────────────────────────────────────────────────
#                                                                    ___________
#                                                                2⋅╲╱ {V_{u}}(t,
#
#                     ∂                                ⎞ ∂
# on_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                     ∂x                               ⎠ ∂y
# ─────────────────────────────────────────────────────────────────────────── -
# _______   __________________
#  x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                    ⎛
# {s_{v,xx}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y,
#                                                    ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                    __________________   ______
#                                                2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v
#
#     ∂                                ⎞ ∂                                2
#  ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {s_{v,xy}} (t, x
#     ∂y                               ⎠ ∂x
# ─────────────────────────────────────────────────────────── - ────────────────
# ____________
# }}(t, x, y)
#
#                 ⎛                              ∂
# , y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω
#                 ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                          __________________   __________________
#                      2⋅╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#   ⎞ ∂                                2                     ⎛
# ))⎟⋅──({V_{u}}(t, x, y))   {s_{v,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(
#   ⎠ ∂y                                                     ⎝
# ──────────────────────── - ───────────────────────────────────────────────────
#                                                                     __________
#                                                                 2⋅╲╱ {V_{u}}(t
#
#             ∂                                ⎞ ∂
# t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {s_{v,xy
#             ∂y                               ⎠ ∂x
# ─────────────────────────────────────────────────────────────────── - ────────
# ________   __________________
# , x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                            ⎛                              ∂
# }}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({
#                                            ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                           __________________   _______________
#                                         ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x,
#
#                              ⎞ ∂
# \varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))
#                              ⎠ ∂y
# ───────────────────────────────────────────────────
# ___
# y)
#                                 __________________           2
#                             2⋅╲╱ {V_{u}}(t, x, y) ⋅{s_{v,xy}} (t, x, y)⋅Expect
# ∂
# ──({s_{v,yy}}(t, x, y)) = - ──────────────────────────────────────────────────
# ∂t
#
#
#      ⎛∂                                 ∂                                ⎞
# ation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2
#      ⎝∂x                                ∂x                               ⎠
# ────────────────────────────────────────────────────────────────────────── - ─
#     __________________
#   ╲╱ {V_{v}}(t, x, y)
#
#    __________________                                                    ⎛∂
# ⋅╲╱ {V_{u}}(t, x, y) ⋅{s_{v,xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜──({
#                                                                          ⎝∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                                                _______________
#                                                              ╲╱ {V_{v}}(t, x,
#
#                               ∂                                ⎞       _______
# \varepsilon_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{u}
#                               ∂y                               ⎠
# ──────────────────────────────────────────────────────────────── - ───────────
# ___
# y)
#
# ___________                                                    ⎛∂
# }(t, x, y) ⋅{s_{v,xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜──({\varepsilo
#                                                                ⎝∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                                      __________________
#                                                    ╲╱ {V_{v}}(t, x, y)
#
#                     ∂                                ⎞       _________________
# n_{u}}(t, x, y, ω))⋅──({\varepsilon_{v}}(t, x, y, ω))⎟   2⋅╲╱ {V_{u}}(t, x, y)
#                     ∂x                               ⎠
# ────────────────────────────────────────────────────── - ─────────────────────
#
#
#
# _           2                     ⎛∂                                 ∂
#  ⋅{s_{v,yy}} (t, x, y)⋅Expectation⎜──({\varepsilon_{u}}(t, x, y, ω))⋅──({\vare
#                                   ⎝∂y                                ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                  __________________
#                                ╲╱ {V_{v}}(t, x, y)
#
#                         ⎞
# psilon_{v}}(t, x, y, ω))⎟       __________________
#                         ⎠   2⋅╲╱ {V_{u}}(t, x, y) ⋅{s_{v,yy}}(t, x, y)⋅Expecta
# ───────────────────────── + ──────────────────────────────────────────────────
#
#                                                                             ╲╱
#
#                                                                       ________
#                                                                     ╲╱ {V_{u}}
# tion({\varepsilon_{u}}(t, x, y, ω)⋅{\varepsilon_{v}}(t, x, y, ω))
# ───────────────────────────────────────────────────────────────── + ──────────
# __________________
#  {V_{v}}(t, x, y)
#
# __________           2                     ⎛                              ∂
# (t, x, y) ⋅{s_{v,xy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({
#                                            ⎝                              ∂x
# ──────────────────────────────────────────────────────────────────────────────
#                                                          3/2
#                                                   {V_{v}}   (t, x, y)
#
#                              ⎞ ∂                        __________________
# \varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{u}}(t, x, y) ⋅{s_
#                              ⎠ ∂x
# ─────────────────────────────────────────────────── + ────────────────────────
#
#
#
#                                                 ⎛
# {v,xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)
#                                                 ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                     3/2
#                                              {V_{v}}   (t, x, y)
#
#  ∂                                ⎞ ∂                        _________________
# ⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{u}}(t, x, y)
#  ∂x                               ⎠ ∂y
# ──────────────────────────────────────────────────────── + ───────────────────
#
#
#
# _                                                    ⎛
#  ⋅{s_{v,xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x,
#                                                      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                          3/2
#                                                   {V_{v}}   (t, x, y)
#
#       ∂                                ⎞ ∂                        ____________
# y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   ╲╱ {V_{u}}(t,
#       ∂y                               ⎠ ∂x
# ───────────────────────────────────────────────────────────── + ──────────────
#
#
#
# ______           2                     ⎛                              ∂
# x, y) ⋅{s_{v,yy}} (t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\var
#                                        ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                                                      3/2
#                                               {V_{v}}   (t, x, y)
#
#                          ⎞ ∂                                2
# epsilon_{v}}(t, x, y, ω))⎟⋅──({V_{v}}(t, x, y))   {s_{v,xy}} (t, x, y)⋅Expecta
#                          ⎠ ∂y
# ─────────────────────────────────────────────── - ────────────────────────────
#
#
#
#     ⎛                              ∂                                ⎞ ∂
# tion⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u
#     ⎝                              ∂x                               ⎠ ∂x
# ──────────────────────────────────────────────────────────────────────────────
#             __________________   __________________
#           ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                                   ⎛
# }}(t, x, y))   {s_{v,xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilo
#                                                                   ⎝
# ──────────── - ───────────────────────────────────────────────────────────────
#                                                                  _____________
#                                                                ╲╱ {V_{u}}(t, x
#
#                    ∂                                ⎞ ∂
# n_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {
#                    ∂x                               ⎠ ∂y
# ────────────────────────────────────────────────────────────────────────── - ─
# _____   __________________
# , y) ⋅╲╱ {V_{v}}(t, x, y)
#
#                                                   ⎛
# s_{v,xy}}(t, x, y)⋅{s_{v,yy}}(t, x, y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y,
#                                                   ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                  __________________   ________
#                                                ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}
#
#    ∂                                ⎞ ∂                                2
# ω)⋅──({\varepsilon_{v}}(t, x, y, ω))⎟⋅──({V_{u}}(t, x, y))   {s_{v,yy}} (t, x,
#    ∂y                               ⎠ ∂x
# ────────────────────────────────────────────────────────── - ─────────────────
# __________
# (t, x, y)
#
#                ⎛                              ∂
#  y)⋅Expectation⎜{\varepsilon_{u}}(t, x, y, ω)⋅──({\varepsilon_{v}}(t, x, y, ω)
#                ⎝                              ∂y
# ──────────────────────────────────────────────────────────────────────────────
#                        __________________   __________________
#                      ╲╱ {V_{u}}(t, x, y) ⋅╲╱ {V_{v}}(t, x, y)
#
#  ⎞ ∂
# )⎟⋅──({V_{u}}(t, x, y))
#  ⎠ ∂y
# ───────────────────────
